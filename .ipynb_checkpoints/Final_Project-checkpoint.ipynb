# %% [markdown]
# # მოდელის ამოცანის დასმა
# <span style="font-size: 16px;">დიეტა უამრავი ადამიანებისთვის ცხოვრების მნიშვნელოვანი ნაწილია; იქნება ეს ჯანმრთელობის გაუმჯობესების, შეხედულების შენარჩუნებისა თუ სხვა მიზეზების გამო. ზოგიერთ შემთხვევაში კი დიეტის მთავარ მიზანს საკვების გარკვეული ნივთიერების კონსისტენტურად მიღება წარმოადგენს. მოცემული მონაცემებიდან ჩვენ გვინდა, რომ ავაგოთ მოდელი, რომელიც მომხმარებელს შესთავაზებს, თუ რა საკვების მიღება არის მისთვის პრიორიტეტი, რათა სწორად მიჰყვეს მის დიეტას და მისთვის სასურველ შედეგს მიაღწიოს.</span>

# %% [markdown]
# <span style="font-size: 16px;">მიზნის მისაღწევად თავდაპირველად დავამუშავებთ მონაცემებს და გამოვიყენებთ ისეთ დიეტებს, რომელთაც მომხმარებლები დიდი სიზუსტით და დარღვევის გარეშე მიჰყვებოდნენ, მიღებული დიეტების შემადგენელ საკვებს კი შემდეგ მომხმარებლისთვის რეკომენდაციისთვის გამოვიყენებთ. მომხმარებელი გადმოგვცემს მონაცემებს, თუ რა არის მისთვის სასურველი/მისაღწევი საკვების ნივთიერებების შემადგენლობა, და თუ დღემდე როგორ მიჰყვებოდა თავის დიეტას, რისი დამუშავებითაც ჩვენი მოდელი ნახავს, თუ სავარაუდოდ რა შემცველობის საკვებს მიიღებს იგი შემდეგ დღეს, და გადაწყვეტს ნავარაუდევი საკვები კარგი არის თუ არა მომხმარებლისთვის და მისი დიეტისთვის, რის შემდეგაც მომხმარებელს მიღებულ შედეგს შეატყობინებს.</span>

# %% [markdown]
# # მონაცემების გაანალიზება

# %% [markdown]
# <span style="font-size: 16px;">**ამოცანის გადაჭრის პირველ ეტაპზე გავარჩიოთ გადმოცემული მონაცემები**</span>

# %% [markdown]
# <span style="font-size: 16px;">თავდაპირველად დავაიმპორტოთ საჭირო ბიბლიოთეკები.</span>

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
# We will need json as the given data and users' diet days are represented as JSON objects 
import json

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

# %% [markdown]
# <span style="font-size: 16px;">შევინახოთ მონაცემები `train` ცვლადში.</span>

# %%
# Store data
train = pd.read_csv('mfp-diaries.tsv', sep='\t')

# %% [markdown]
# <span style="font-size: 16px;">ვნახოთ, თუ როგორ გამოიყურება და რა სახის ფორმატში გვაქვს გადმოცემული მონაცემები</span>

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587186 entries, 0 to 587185
# Data columns (total 4 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Non-Null Count   Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      --------------   -----
#  0   1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           587186 non-null  int64
#  1   2014-09-14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  587186 non-null  object
#  2   [{"meal": "MY food", "dishes": [{"nutritions": [{"name": "Calories", "value": "412"}, {"name": "Carbs", "value": "29"}, {"name": "Fat", "value": "24"}, {"name": "Protein", "value": "21"}, {"name": "Sodium", "value": "258"}, {"name": "Sugar", "value": "29"}], "name": "my - McDonalds Espresso Pronto\u00ae Flat White, 2 TALL"}, {"nutritions": [{"name": "Calories", "value": "170"}, {"name": "Carbs", "value": "25"}, {"name": "Fat", "value": "5"}, {"name": "Protein", "value": "20"}, {"name": "Sodium", "value": "260"}, {"name": "Sugar", "value": "2"}], "name": "Quest Bar - Banana Nut Muffin Natural Protein Bar, 60 g"}, {"nutritions": [{"name": "Calories", "value": "176"}, {"name": "Carbs", "value": "33"}, {"name": "Fat", "value": "1"}, {"name": "Protein", "value": "5"}, {"name": "Sodium", "value": "195"}, {"name": "Sugar", "value": "0"}], "name": "Uncle Tobys Australia - Vita Brits, 3 Biscuits 33.3g"}, {"nutritions": [{"name": "Calories", "value": "342"}, {"name": "Carbs", "value": "34"}, {"name": "Fat", "value": "12"}, {"name": "Protein", "value": "24"}, {"name": "Sodium", "value": "402"}, {"name": "Sugar", "value": "34"}], "name": "Pauls - Smarter White Milk, 600 ml"}, {"nutritions": [{"name": "Calories", "value": "180"}, {"name": "Carbs", "value": "22"}, {"name": "Fat", "value": "7"}, {"name": "Protein", "value": "21"}, {"name": "Sodium", "value": "310"}, {"name": "Sugar", "value": "1"}], "name": "Quest Bar - Cookies and Cream, 1 bar"}, {"nutritions": [{"name": "Calories", "value": "180"}, {"name": "Carbs", "value": "46"}, {"name": "Fat", "value": "0"}, {"name": "Protein", "value": "0"}, {"name": "Sodium", "value": "100"}, {"name": "Sugar", "value": "22"}], "name": "Gu Sports - Chomps, 8 pieces"}, {"nutritions": [{"name": "Calories", "value": "170"}, {"name": "Carbs", "value": "25"}, {"name": "Fat", "value": "5"}, {"name": "Protein", "value": "20"}, {"name": "Sodium", "value": "260"}, {"name": "Sugar", "value": "2"}], "name": "Quest Bar - Banana Nut Muffin Natural Protein Bar, 60 g"}, {"nutritions": [{"name": "Calories", "value": "160"}, {"name": "Carbs", "value": "25"}, {"name": "Fat", "value": "5"}, {"name": "Protein", "value": "20"}, {"name": "Sodium", "value": "240"}, {"name": "Sugar", "value": "2"}], "name": "Quest - Protein Bar Chocolate Peanut Butter, 1 bar (60 g)"}, {"nutritions": [{"name": "Calories", "value": "686"}, {"name": "Carbs", "value": "59"}, {"name": "Fat", "value": "31"}, {"name": "Protein", "value": "40"}, {"name": "Sodium", "value": "1,105"}, {"name": "Sugar", "value": "9"}], "name": "Grilld - Simply Grilled (Real), 1.25 burger"}, {"nutritions": [{"name": "Calories", "value": "252"}, {"name": "Carbs", "value": "27"}, {"name": "Fat", "value": "14"}, {"name": "Protein", "value": "5"}, {"name": "Sodium", "value": "352"}, {"name": "Sugar", "value": "1"}], "name": "Grilld - Snack Chips, 1 snack size"}, {"nutritions": [{"name": "Calories", "value": "196"}, {"name": "Carbs", "value": "15"}, {"name": "Fat", "value": "10"}, {"name": "Protein", "value": "10"}, {"name": "Sodium", "value": "176"}, {"name": "Sugar", "value": "7"}], "name": "Tasti - Salted Caramel Protein Bar, 40 g"}], "sequence": 1}]  587186 non-null  object
#  3   {"total": [{"name": "Calories", "value": 2924}, {"name": "Carbs", "value": 340}, {"name": "Fat", "value": 114}, {"name": "Protein", "value": 186}, {"name": "Sodium", "value": 3658}, {"name": "Sugar", "value": 109}], "goal": [{"name": "Calories", "value": 3173}, {"name": "Carbs", "value": 396}, {"name": "Fat", "value": 105}, {"name": "Protein", "value": 160}, {"name": "Sodium", "value": 2300}, {"name": "Sugar", "value": 119}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               587186 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 17.9+ MB

# %% [markdown]
# <span style="font-size: 16px;">მონაცემებზე კარგად დაკვირვებით ვხედავთ, რომ ჩვენი მონაცემები შედგება **მომხმარებლის იდენტიფიკატორით**, **თარიღით**, მიმდინარე დღეს **მიღებული საკვების ნივთიერებების რაოდენობითა** და მისი მიმდინარე დღის **სასურველი ნივთიერებების მიღების რაოდენობით (მიზანი)**. მონაცემების უკეთ დასანახად/გასანაწილებლად ვნახოთ პირველი მომხმარებლის პირველი დღის ჩანაწერი:</span>

# %%
def get_details_for_index(data, row_index):
    """This function returns details of user data for given row index (user_id, date, food entries, goal)"""
    # Id of the first user
    user_id = data.iloc[row_index, 0]
    # Date of the first user's first day of the diet
    date = data.iloc[row_index, 1]
    # User's intake of neutrients for the day
    food_entries = json.loads(data.iloc[row_index, 2])
    #ser's goal intake of neutrients for the day
    intake_goal = json.loads(data.iloc[row_index, 3])
    
    return (user_id, date, food_entries, intake_goal)

# %%
for i in range(1, 2):
    details = get_details_for_index(train, i)

    print('\n------------- User ' + str(details[0]) + ' Date ' + str(details[1]) + ' -------------\n')
    print('------------- Food Entries -------------')
    print(json.dumps(details[2], indent=2))
    print('\n------------- Sum -------------')
    print(json.dumps(details[3], indent=2))
    
    print(details[3]['goal'])
    goals = details[3]['goal']
    ress = 0
    for j in range(len(goals)):
        ress += goals[j]['value']
        print(ress)
# Out:
# ------------- User 1 Date 2014-09-16 -------------
#
# ------------- Food Entries -------------
# [
#   {
#     "meal": "MY food",
#     "dishes": [
#       {
#         "nutritions": [
#           {
#             "name": "Calories",
#             "value": "147"
#           },
#           {
#             "name": "Carbs",
#             "value": "36"
#           },
#           {
#             "name": "Fat",
#             "value": "0"
#           },
#           {
#             "name": "Protein",
#             "value": "0"
#           },
#           {
#             "name": "Sodium",
#             "value": "306"
#           },
#           {
#             "name": "Sugar",
#             "value": "36"
#           }
#         ],
#         "name": "Gatorade - Lemon-Lime (Australia), 600 ml"
#       },
#       {
#         "nutritions": [
#           {
#             "name": "Calories",
#             "value": "412"
#           },
#           {
#             "name": "Carbs",
#             "value": "29"
#           },
#           {
#             "name": "Fat",
#             "value": "24"
#           },
#           {
#             "name": "Protein",
#             "value": "21"
#           },
#           {
#             "name": "Sodium",
#             "value": "258"
#           },
#           {
#             "name": "Sugar",
#             "value": "29"
#           }
#         ],
#         "name": "my - McDonalds Espresso Pronto\u00ae Flat White, 2 TALL"
#       },
#       {
#         "nutritions": [
#           {
#             "name": "Calories",
#             "value": "176"
#           },
#           {
#             "name": "Carbs",
#             "value": "33"
#           },
#           {
#             "name": "Fat",
#             "value": "1"
#           },
#           {
#             "name": "Protein",
#             "value": "5"
#           },
#           {
#             "name": "Sodium",
#             "value": "195"
#           },
#           {
#             "name": "Sugar",
#             "value": "0"
#           }
#         ],
#         "name": "Uncle Tobys Australia - Vita Brits, 3 Biscuits 33.3g"
#       },
#       {
#         "nutritions": [
#           {
#             "name": "Calories",
#             "value": "342"
#           },
#           {
#             "name": "Carbs",
#             "value": "34"
#           },
#           {
#             "name": "Fat",
#             "value": "12"
#           },
#           {
#             "name": "Protein",
#             "value": "24"
#           },
#           {
#             "name": "Sodium",
#             "value": "402"
#           },
#           {
#             "name": "Sugar",
#             "value": "34"
#           }
#         ],
#         "name": "Pauls - Smarter White Milk, 600 ml"
#       },
#       {
#         "nutritions": [
#           {
#             "name": "Calories",
#             "value": "145"
#           },
#           {
#             "name": "Carbs",
#             "value": "2"
#           },
#           {
#             "name": "Fat",
#             "value": "1"
#           },
#           {
#             "name": "Protein",
#             "value": "32"
#           },
#           {
#             "name": "Sodium",
#             "value": "70"
#           },
#           {
#             "name": "Sugar",
#             "value": "1"
#           }
#         ],
#         "name": "Redbak - Sting-chocolate, 40 g"
#       },
#       {
#         "nutritions": [
#           {
#             "name": "Calories",
#             "value": "640"
#           },
#           {
#             "name": "Carbs",
#             "value": "24"
#           },
#           {
#             "name": "Fat",
#             "value": "16"
#           },
#           {
#             "name": "Protein",
#             "value": "32"
#           },
#           {
#             "name": "Sodium",
#             "value": "984"
#           },
#           {
#             "name": "Sugar",
#             "value": "0"
#           }
#         ],
#         "name": "Generic - Pork Dumplings - Steamed, 8 Dumpling"
#       }
#     ],
#     "sequence": 1
#   }
# ]
#
# ------------- Sum -------------
# {
#   "total": [
#     {
#       "name": "Calories",
#       "value": 1862
#     },
#     {
#       "name": "Carbs",
#       "value": 158
#     },
#     {
#       "name": "Fat",
#       "value": 54
#     },
#     {
#       "name": "Protein",
#       "value": 114
#     },
#     {
#       "name": "Sodium",
#       "value": 2215
#     },
#     {
#       "name": "Sugar",
#       "value": 100
#     }
#   ],
#   "goal": [
#     {
#       "name": "Calories",
#       "value": 1832
#     },
#     {
#       "name": "Carbs",
#       "value": 229
#     },
#     {
#       "name": "Fat",
#       "value": 61
#     },
#     {
#       "name": "Protein",
#       "value": 92
#     },
#     {
#       "name": "Sodium",
#       "value": 2300
#     },
#     {
#       "name": "Sugar",
#       "value": 69
#     }
#   ]
# }
# [{'name': 'Calories', 'value': 1832}, {'name': 'Carbs', 'value': 229}, {'name': 'Fat', 'value': 61}, {'name': 'Protein', 'value': 92}, {'name': 'Sodium', 'value': 2300}, {'name': 'Sugar', 'value': 69}]
# 1832
# 2061
# 2122
# 2214
# 4514
# 4583

# %% [markdown]
# <span style="font-size: 16px;">მონაცემების ვიზუალურად წარმოსაჩენად დამხმარე ფუნქციები:</span>

# %%
def plot_items(items, x_label, y_label, title, colors = None, width = 7):
    """Plots given items' values"""
    rcParams['figure.figsize'] = width, 5
    # Prepare labels and values for the graph
    indexes = []
    counts = []
    index_labels = []
    i = 1
    for item_name, item_count in items.items():
        print('> ' + str(item_name) + ': ' + str(item_count))
        indexes.append(i)
        counts.append(item_count)
        index_labels.append(item_name)
        i += 1

    # Plot the graph
    if colors is not None:
        plt.bar(indexes, counts, tick_label = index_labels, width = 0.8, color = colors)
    else:
        plt.bar(indexes, counts, tick_label = index_labels, width = 0.8)

    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title) 
    
    plt.show()
    
def plot_pie_with_legend(items):
    """Plots given items' value percentages with legend"""
    labels = []
    sizes = []
    for x, y in items.items():
        labels.append(x)
        sizes.append(y)

    fig, ax = plt.subplots(figsize=(6, 5))
    fig.subplots_adjust(0.3,0,1,1)
    
    theme = plt.get_cmap('viridis')
    ax.set_prop_cycle("color", [theme(1. * i / len(sizes)) for i in range(len(sizes))])

    _, _ = ax.pie(sizes, startangle=90, radius=1800)

    ax.axis('equal')
    plt.legend(
        loc = 'upper left',
        labels = ['%s - %1.1f%%' % (l, (float(s) / sum(sizes)) * 100) for l, s in zip(labels, sizes)],
        prop = {'size': 15},
        bbox_to_anchor = (-0.3, 1),
        bbox_transform = fig.transFigure
    )

    plt.show()

# %% [markdown]
# <span style="font-size: 16px;">მონაცემების გასაანალიზებლად და იმის დასადგენად, თუ რომელი დიეტები შეგვიძლია ჩავთვალოთ **კარგად** (იგულისხმება თუ რამდენად სწორად მიყვებოდა და რამხელა სიდიდით დაარღვია პიროვნებამ მისი დიეტა) ვნახოთ, თუ **საშუალოდ რამდენად ცდება** თითოეული პიროვნება მის განსაზღვრულ/სასურველ ნივთიერებათა რაოდენობას. დავითვალოთ თუ რა რაოდენობის ნივთიერება მიიღო მომხმარებელმა მისი მთლიანი დიეტის პერიოდში და რამდენის მიღება ჰქონდა გასაზღვრული, შემდეგ კი დავთვალოთ საშუალო აცდენა</span>

# %%
curr_user_id = train.iloc[0, 0]
users_intakes = {}
users_goals = {}
for i in range(len(train.index)):
    # Get the details of the day for the current row
    curr_day_user_id = train.iloc[i, 0]
    # Add user to dict if not present
    if curr_day_user_id not in users_intakes:
        users_intakes[curr_day_user_id] = {'sum' : 0}
        users_goals[curr_day_user_id] = {'sum' : 0}
        
    curr_sum = json.loads(train.iloc[i, 3])
    
    curr_intakes = curr_sum['total']
    for n in range(len(curr_intakes)):
        _name = curr_intakes[n]['name']
        _value = curr_intakes[n]['value']
        if _name not in users_intakes[curr_day_user_id]:
            users_intakes[curr_day_user_id][_name] = _value
        else:
            users_intakes[curr_day_user_id][_name] += _value
        users_intakes[curr_day_user_id]['sum'] += _value
        
    curr_goals = curr_sum['goal']
    for n in range(len(curr_goals)):
        _name = curr_goals[n]['name']
        _value = curr_goals[n]['value']
        if _name not in users_goals[curr_day_user_id]:
            users_goals[curr_day_user_id][_name] = _value
        else:
            users_goals[curr_day_user_id][_name] += _value
        users_goals[curr_day_user_id]['sum'] += _value

#Now we count absolute differences between each users intake and their goals
users_diffs = {}
for i in users_intakes:
    users_diffs[i] = abs(users_intakes[i]['sum'] - users_goals[i]['sum'])

# %% [markdown]
# <span style="font-size: 16px;">მიღებული მონაცემები თითოეულ მომხმარებელზე:</span>

# %%
for i in users_intakes:
    print('მომხმარებელი {0}: მიიღო {1}, განსაზღვრული {2}, სხვაობა {3};'.format(str(i), 
        str(users_intakes[i]['sum']), str(users_goals[i]['sum']), str(users_diffs[i])))
# Out:
# მომხმარებელი 1: მიიღო 837368, განსაზღვრული 861242, სხვაობა 23874;
# მომხმარებელი 2: მიიღო 208179, განსაზღვრული 251403, სხვაობა 43224;
# მომხმარებელი 3: მიიღო 23646, განსაზღვრული 27693, სხვაობა 4047;
# მომხმარებელი 4: მიიღო 86279, განსაზღვრული 210022, სხვაობა 123743;
# მომხმარებელი 5: მიიღო 970881, განსაზღვრული 1064788, სხვაობა 93907;
# მომხმარებელი 6: მიიღო 186319, განსაზღვრული 219263, სხვაობა 32944;
# მომხმარებელი 7: მიიღო 16220, განსაზღვრული 25576, სხვაობა 9356;
# მომხმარებელი 8: მიიღო 186062, განსაზღვრული 195611, სხვაობა 9549;
# მომხმარებელი 9: მიიღო 2462, განსაზღვრული 4364, სხვაობა 1902;
# მომხმარებელი 10: მიიღო 240470, განსაზღვრული 265417, სხვაობა 24947;
# მომხმარებელი 11: მიიღო 32827, განსაზღვრული 45925, სხვაობა 13098;
# მომხმარებელი 12: მიიღო 321885, განსაზღვრული 570790, სხვაობა 248905;
# მომხმარებელი 13: მიიღო 263858, განსაზღვრული 324627, სხვაობა 60769;
# მომხმარებელი 14: მიიღო 7473, განსაზღვრული 16043, სხვაობა 8570;
# მომხმარებელი 15: მიიღო 45012, განსაზღვრული 49206, სხვაობა 4194;
# მომხმარებელი 16: მიიღო 275359, განსაზღვრული 454291, სხვაობა 178932;
# მომხმარებელი 17: მიიღო 67677, განსაზღვრული 125693, სხვაობა 58016;
# მომხმარებელი 18: მიიღო 78541, განსაზღვრული 81479, სხვაობა 2938;
# მომხმარებელი 19: მიიღო 32611, განსაზღვრული 45425, სხვაობა 12814;
# მომხმარებელი 20: მიიღო 58256, განსაზღვრული 71779, სხვაობა 13523;
# მომხმარებელი 21: მიიღო 128459, განსაზღვრული 132698, სხვაობა 4239;
# მომხმარებელი 22: მიიღო 11249, განსაზღვრული 18975, სხვაობა 7726;
# მომხმარებელი 23: მიიღო 55615, განსაზღვრული 69770, სხვაობა 14155;
# მომხმარებელი 24: მიიღო 49504, განსაზღვრული 109288, სხვაობა 59784;
# მომხმარებელი 25: მიიღო 25774, განსაზღვრული 62599, სხვაობა 36825;
# მომხმარებელი 26: მიიღო 38896, განსაზღვრული 80696, სხვაობა 41800;
# მომხმარებელი 27: მიიღო 55, განსაზღვრული 2502, სხვაობა 2447;
# მომხმარებელი 28: მიიღო 7725, განსაზღვრული 11293, სხვაობა 3568;
# მომხმარებელი 29: მიიღო 83333, განსაზღვრული 101386, სხვაობა 18053;
# მომხმარებელი 30: მიიღო 39045, განსაზღვრული 63019, სხვაობა 23974;
# მომხმარებელი 31: მიიღო 1376638, განსაზღვრული 1629438, სხვაობა 252800;
# მომხმარებელი 32: მიიღო 199138, განსაზღვრული 233114, სხვაობა 33976;
# მომხმარებელი 33: მიიღო 97215, განსაზღვრული 119868, სხვაობა 22653;
# მომხმარებელი 34: მიიღო 237529, განსაზღვრული 264266, სხვაობა 26737;
# მომხმარებელი 35: მიიღო 21575, განსაზღვრული 38891, სხვაობა 17316;
# მომხმარებელი 36: მიიღო 697858, განსაზღვრული 574134, სხვაობა 123724;
# მომხმარებელი 37: მიიღო 129001, განსაზღვრული 124828, სხვაობა 4173;
# მომხმარებელი 38: მიიღო 150504, განსაზღვრული 738642, სხვაობა 588138;
# მომხმარებელი 39: მიიღო 1702, განსაზღვრული 4966, სხვაობა 3264;
# მომხმარებელი 40: მიიღო 98572, განსაზღვრული 205443, სხვაობა 106871;
# მომხმარებელი 41: მიიღო 170646, განსაზღვრული 309283, სხვაობა 138637;
# მომხმარებელი 42: მიიღო 42333, განსაზღვრული 111732, სხვაობა 69399;
# მომხმარებელი 43: მიიღო 339138, განსაზღვრული 395146, სხვაობა 56008;
# მომხმარებელი 44: მიიღო 213326, განსაზღვრული 354516, სხვაობა 141190;
# მომხმარებელი 45: მიიღო 61189, განსაზღვრული 56905, სხვაობა 4284;
# მომხმარებელი 46: მიიღო 481293, განსაზღვრული 957624, სხვაობა 476331;
# მომხმარებელი 47: მიიღო 863437, განსაზღვრული 765609, სხვაობა 97828;
# მომხმარებელი 48: მიიღო 354329, განსაზღვრული 494393, სხვაობა 140064;
# მომხმარებელი 49: მიიღო 22879, განსაზღვრული 37326, სხვაობა 14447;
# მომხმარებელი 50: მიიღო 387147, განსაზღვრული 461043, სხვაობა 73896;
# მომხმარებელი 51: მიიღო 160517, განსაზღვრული 257222, სხვაობა 96705;
# მომხმარებელი 52: მიიღო 311398, განსაზღვრული 292495, სხვაობა 18903;
# მომხმარებელი 53: მიიღო 21898, განსაზღვრული 45473, სხვაობა 23575;
# მომხმარებელი 54: მიიღო 3380, განსაზღვრული 10219, სხვაობა 6839;
# მომხმარებელი 55: მიიღო 4813, განსაზღვრული 10555, სხვაობა 5742;
# მომხმარებელი 56: მიიღო 235850, განსაზღვრული 359831, სხვაობა 123981;
# მომხმარებელი 57: მიიღო 92006, განსაზღვრული 149159, სხვაობა 57153;
# მომხმარებელი 58: მიიღო 2097, განსაზღვრული 4344, სხვაობა 2247;
# მომხმარებელი 59: მიიღო 387070, განსაზღვრული 417887, სხვაობა 30817;
# მომხმარებელი 60: მიიღო 3553, განსაზღვრული 8345, სხვაობა 4792;
# მომხმარებელი 61: მიიღო 1501, განსაზღვრული 3086, სხვაობა 1585;
# მომხმარებელი 62: მიიღო 90775, განსაზღვრული 190955, სხვაობა 100180;
# მომხმარებელი 63: მიიღო 410924, განსაზღვრული 601139, სხვაობა 190215;
# მომხმარებელი 64: მიიღო 13260, განსაზღვრული 19243, სხვაობა 5983;
# მომხმარებელი 65: მიიღო 14548, განსაზღვრული 24097, სხვაობა 9549;
# მომხმარებელი 66: მიიღო 192583, განსაზღვრული 246658, სხვაობა 54075;
# მომხმარებელი 67: მიიღო 277235, განსაზღვრული 307171, სხვაობა 29936;
# მომხმარებელი 68: მიიღო 881668, განსაზღვრული 805305, სხვაობა 76363;
# მომხმარებელი 69: მიიღო 579, განსაზღვრული 3899, სხვაობა 3320;
# მომხმარებელი 70: მიიღო 82201, განსაზღვრული 141991, სხვაობა 59790;
# მომხმარებელი 71: მიიღო 150262, განსაზღვრული 228178, სხვაობა 77916;
# მომხმარებელი 72: მიიღო 486061, განსაზღვრული 511894, სხვაობა 25833;
# მომხმარებელი 73: მიიღო 29441, განსაზღვრული 63107, სხვაობა 33666;
# მომხმარებელი 74: მიიღო 51070, განსაზღვრული 98866, სხვაობა 47796;
# მომხმარებელი 75: მიიღო 85390, განსაზღვრული 126133, სხვაობა 40743;
# მომხმარებელი 76: მიიღო 169874, განსაზღვრული 152836, სხვაობა 17038;
# მომხმარებელი 77: მიიღო 1961, განსაზღვრული 60632, სხვაობა 58671;
# მომხმარებელი 78: მიიღო 382361, განსაზღვრული 568157, სხვაობა 185796;
# მომხმარებელი 79: მიიღო 72768, განსაზღვრული 82054, სხვაობა 9286;
# მომხმარებელი 80: მიიღო 14796, განსაზღვრული 20205, სხვაობა 5409;
# მომხმარებელი 81: მიიღო 33631, განსაზღვრული 51491, სხვაობა 17860;
# მომხმარებელი 82: მიიღო 599300, განსაზღვრული 781593, სხვაობა 182293;
# მომხმარებელი 83: მიიღო 3298, განსაზღვრული 3775, სხვაობა 477;
# მომხმარებელი 84: მიიღო 155057, განსაზღვრული 170883, სხვაობა 15826;
# მომხმარებელი 85: მიიღო 491037, განსაზღვრული 567361, სხვაობა 76324;
# მომხმარებელი 86: მიიღო 344779, განსაზღვრული 495157, სხვაობა 150378;
# მომხმარებელი 87: მიიღო 473, განსაზღვრული 2029, სხვაობა 1556;
# მომხმარებელი 88: მიიღო 132767, განსაზღვრული 211627, სხვაობა 78860;
# მომხმარებელი 89: მიიღო 438875, განსაზღვრული 633215, სხვაობა 194340;
# მომხმარებელი 90: მიიღო 229009, განსაზღვრული 290383, სხვაობა 61374;
# მომხმარებელი 91: მიიღო 331157, განსაზღვრული 381673, სხვაობა 50516;
# მომხმარებელი 92: მიიღო 41158, განსაზღვრული 46831, სხვაობა 5673;
# მომხმარებელი 93: მიიღო 35624, განსაზღვრული 65450, სხვაობა 29826;
# მომხმარებელი 94: მიიღო 14787, განსაზღვრული 21540, სხვაობა 6753;
# მომხმარებელი 95: მიიღო 657751, განსაზღვრული 698721, სხვაობა 40970;
# მომხმარებელი 96: მიიღო 4365, განსაზღვრული 8528, სხვაობა 4163;
# მომხმარებელი 97: მიიღო 9065, განსაზღვრული 23210, სხვაობა 14145;
# მომხმარებელი 98: მიიღო 6817, განსაზღვრული 8297, სხვაობა 1480;
# მომხმარებელი 99: მიიღო 244781, განსაზღვრული 271782, სხვაობა 27001;
# მომხმარებელი 100: მიიღო 88148, განსაზღვრული 213466, სხვაობა 125318;
# მომხმარებელი 101: მიიღო 181076, განსაზღვრული 228846, სხვაობა 47770;
# მომხმარებელი 102: მიიღო 69062, განსაზღვრული 121499, სხვაობა 52437;
# მომხმარებელი 103: მიიღო 126476, განსაზღვრული 171242, სხვაობა 44766;
# მომხმარებელი 104: მიიღო 300687, განსაზღვრული 313141, სხვაობა 12454;
# მომხმარებელი 105: მიიღო 12272, განსაზღვრული 28554, სხვაობა 16282;
# მომხმარებელი 106: მიიღო 57135, განსაზღვრული 79308, სხვაობა 22173;
# მომხმარებელი 107: მიიღო 37785, განსაზღვრული 36192, სხვაობა 1593;
# მომხმარებელი 108: მიიღო 318659, განსაზღვრული 393103, სხვაობა 74444;
# მომხმარებელი 109: მიიღო 412762, განსაზღვრული 505525, სხვაობა 92763;
# მომხმარებელი 110: მიიღო 18891, განსაზღვრული 38256, სხვაობა 19365;
# მომხმარებელი 111: მიიღო 80701, განსაზღვრული 128141, სხვაობა 47440;
# მომხმარებელი 112: მიიღო 362036, განსაზღვრული 110266, სხვაობა 251770;
# მომხმარებელი 113: მიიღო 513624, განსაზღვრული 482754, სხვაობა 30870;
# მომხმარებელი 114: მიიღო 73841, განსაზღვრული 111593, სხვაობა 37752;
# მომხმარებელი 115: მიიღო 267182, განსაზღვრული 295679, სხვაობა 28497;
# მომხმარებელი 116: მიიღო 291238, განსაზღვრული 359483, სხვაობა 68245;
# მომხმარებელი 117: მიიღო 15043, განსაზღვრული 26355, სხვაობა 11312;
# მომხმარებელი 118: მიიღო 20469, განსაზღვრული 36486, სხვაობა 16017;
# მომხმარებელი 119: მიიღო 213380, განსაზღვრული 210747, სხვაობა 2633;
# მომხმარებელი 120: მიიღო 127831, განსაზღვრული 463136, სხვაობა 335305;
# მომხმარებელი 121: მიიღო 9354, განსაზღვრული 13181, სხვაობა 3827;
# მომხმარებელი 122: მიიღო 263762, განსაზღვრული 376426, სხვაობა 112664;
# მომხმარებელი 123: მიიღო 190352, განსაზღვრული 345715, სხვაობა 155363;
# მომხმარებელი 124: მიიღო 36469, განსაზღვრული 35354, სხვაობა 1115;
# მომხმარებელი 125: მიიღო 263122, განსაზღვრული 320736, სხვაობა 57614;
# მომხმარებელი 126: მიიღო 96039, განსაზღვრული 145977, სხვაობა 49938;
# მომხმარებელი 127: მიიღო 11055, განსაზღვრული 43108, სხვაობა 32053;
# მომხმარებელი 128: მიიღო 141983, განსაზღვრული 333833, სხვაობა 191850;
# მომხმარებელი 129: მიიღო 188291, განსაზღვრული 308197, სხვაობა 119906;
# მომხმარებელი 130: მიიღო 131465, განსაზღვრული 145746, სხვაობა 14281;
# მომხმარებელი 131: მიიღო 327852, განსაზღვრული 395496, სხვაობა 67644;
# მომხმარებელი 132: მიიღო 39460, განსაზღვრული 62722, სხვაობა 23262;
# მომხმარებელი 133: მიიღო 44478, განსაზღვრული 80677, სხვაობა 36199;
# მომხმარებელი 134: მიიღო 171130, განსაზღვრული 310732, სხვაობა 139602;
# მომხმარებელი 135: მიიღო 195454, განსაზღვრული 294765, სხვაობა 99311;
# მომხმარებელი 136: მიიღო 358741, განსაზღვრული 419779, სხვაობა 61038;
# მომხმარებელი 137: მიიღო 206943, განსაზღვრული 260678, სხვაობა 53735;
# მომხმარებელი 138: მიიღო 162711, განსაზღვრული 272101, სხვაობა 109390;
# მომხმარებელი 139: მიიღო 4933, განსაზღვრული 9246, სხვაობა 4313;
# მომხმარებელი 140: მიიღო 21064, განსაზღვრული 17550, სხვაობა 3514;
# მომხმარებელი 141: მიიღო 162228, განსაზღვრული 212088, სხვაობა 49860;
# მომხმარებელი 142: მიიღო 9806, განსაზღვრული 24035, სხვაობა 14229;
# მომხმარებელი 143: მიიღო 310722, განსაზღვრული 375510, სხვაობა 64788;
# მომხმარებელი 144: მიიღო 1074023, განსაზღვრული 896735, სხვაობა 177288;
# მომხმარებელი 145: მიიღო 214020, განსაზღვრული 294673, სხვაობა 80653;
# მომხმარებელი 146: მიიღო 202221, განსაზღვრული 285307, სხვაობა 83086;
# მომხმარებელი 147: მიიღო 68459, განსაზღვრული 62812, სხვაობა 5647;
# მომხმარებელი 148: მიიღო 55317, განსაზღვრული 57081, სხვაობა 1764;
# მომხმარებელი 149: მიიღო 21866, განსაზღვრული 28882, სხვაობა 7016;
# მომხმარებელი 150: მიიღო 41883, განსაზღვრული 48411, სხვაობა 6528;
# მომხმარებელი 151: მიიღო 185566, განსაზღვრული 281616, სხვაობა 96050;
# მომხმარებელი 152: მიიღო 195646, განსაზღვრული 297455, სხვაობა 101809;
# მომხმარებელი 153: მიიღო 31993, განსაზღვრული 50079, სხვაობა 18086;
# მომხმარებელი 154: მიიღო 190112, განსაზღვრული 211578, სხვაობა 21466;
# მომხმარებელი 155: მიიღო 4078, განსაზღვრული 7364, სხვაობა 3286;
# მომხმარებელი 156: მიიღო 320219, განსაზღვრული 346533, სხვაობა 26314;
# მომხმარებელი 157: მიიღო 611314, განსაზღვრული 718797, სხვაობა 107483;
# მომხმარებელი 158: მიიღო 781, განსაზღვრული 7146, სხვაობა 6365;
# მომხმარებელი 159: მიიღო 553931, განსაზღვრული 657569, სხვაობა 103638;
# მომხმარებელი 160: მიიღო 55499, განსაზღვრული 79013, სხვაობა 23514;
# მომხმარებელი 161: მიიღო 66143, განსაზღვრული 64298, სხვაობა 1845;
# მომხმარებელი 162: მიიღო 32899, განსაზღვრული 45024, სხვაობა 12125;
# მომხმარებელი 163: მიიღო 28587, განსაზღვრული 30086, სხვაობა 1499;
# მომხმარებელი 164: მიიღო 22089, განსაზღვრული 21588, სხვაობა 501;
# მომხმარებელი 165: მიიღო 389256, განსაზღვრული 358967, სხვაობა 30289;
# მომხმარებელი 166: მიიღო 10189, განსაზღვრული 21357, სხვაობა 11168;
# მომხმარებელი 167: მიიღო 72308, განსაზღვრული 135634, სხვაობა 63326;
# მომხმარებელი 168: მიიღო 374322, განსაზღვრული 540881, სხვაობა 166559;
# მომხმარებელი 169: მიიღო 5222, განსაზღვრული 10616, სხვაობა 5394;
# მომხმარებელი 170: მიიღო 69803, განსაზღვრული 79102, სხვაობა 9299;
# მომხმარებელი 171: მიიღო 61460, განსაზღვრული 90821, სხვაობა 29361;
# მომხმარებელი 172: მიიღო 80370, განსაზღვრული 141849, სხვაობა 61479;
# მომხმარებელი 173: მიიღო 489345, განსაზღვრული 627037, სხვაობა 137692;
# მომხმარებელი 174: მიიღო 615192, განსაზღვრული 505875, სხვაობა 109317;
# მომხმარებელი 175: მიიღო 387477, განსაზღვრული 666002, სხვაობა 278525;
# მომხმარებელი 176: მიიღო 43749, განსაზღვრული 46231, სხვაობა 2482;
# მომხმარებელი 177: მიიღო 36015, განსაზღვრული 48160, სხვაობა 12145;
# მომხმარებელი 178: მიიღო 77026, განსაზღვრული 103641, სხვაობა 26615;
# მომხმარებელი 179: მიიღო 52698, განსაზღვრული 69156, სხვაობა 16458;
# მომხმარებელი 180: მიიღო 161055, განსაზღვრული 191326, სხვაობა 30271;
# მომხმარებელი 181: მიიღო 871261, განსაზღვრული 783589, სხვაობა 87672;
# მომხმარებელი 182: მიიღო 17848, განსაზღვრული 40092, სხვაობა 22244;
# მომხმარებელი 183: მიიღო 7916, განსაზღვრული 8544, სხვაობა 628;
# მომხმარებელი 184: მიიღო 6898, განსაზღვრული 11245, სხვაობა 4347;
# მომხმარებელი 185: მიიღო 19824, განსაზღვრული 37377, სხვაობა 17553;
# მომხმარებელი 186: მიიღო 174061, განსაზღვრული 202703, სხვაობა 28642;
# მომხმარებელი 187: მიიღო 1423, განსაზღვრული 3810, სხვაობა 2387;
# მომხმარებელი 188: მიიღო 127255, განსაზღვრული 181953, სხვაობა 54698;
# მომხმარებელი 189: მიიღო 198039, განსაზღვრული 352176, სხვაობა 154137;
# მომხმარებელი 190: მიიღო 221862, განსაზღვრული 295746, სხვაობა 73884;
# მომხმარებელი 191: მიიღო 290815, განსაზღვრული 388481, სხვაობა 97666;
# მომხმარებელი 192: მიიღო 83574, განსაზღვრული 149520, სხვაობა 65946;
# მომხმარებელი 193: მიიღო 83832, განსაზღვრული 123349, სხვაობა 39517;
# მომხმარებელი 194: მიიღო 676417, განსაზღვრული 761211, სხვაობა 84794;
# მომხმარებელი 195: მიიღო 1939, განსაზღვრული 4142, სხვაობა 2203;
# მომხმარებელი 196: მიიღო 226835, განსაზღვრული 305527, სხვაობა 78692;
# მომხმარებელი 197: მიიღო 53480, განსაზღვრული 70706, სხვაობა 17226;
# მომხმარებელი 198: მიიღო 3281, განსაზღვრული 4031, სხვაობა 750;
# მომხმარებელი 199: მიიღო 563731, განსაზღვრული 581755, სხვაობა 18024;
# მომხმარებელი 200: მიიღო 356195, განსაზღვრული 413645, სხვაობა 57450;
# მომხმარებელი 201: მიიღო 167676, განსაზღვრული 303932, სხვაობა 136256;
# მომხმარებელი 202: მიიღო 36536, განსაზღვრული 59360, სხვაობა 22824;
# მომხმარებელი 203: მიიღო 244512, განსაზღვრული 250879, სხვაობა 6367;
# მომხმარებელი 204: მიიღო 390157, განსაზღვრული 395539, სხვაობა 5382;
# მომხმარებელი 205: მიიღო 312174, განსაზღვრული 353139, სხვაობა 40965;
# მომხმარებელი 206: მიიღო 127752, განსაზღვრული 280855, სხვაობა 153103;
# მომხმარებელი 207: მიიღო 323804, განსაზღვრული 345805, სხვაობა 22001;
# მომხმარებელი 208: მიიღო 25835, განსაზღვრული 38298, სხვაობა 12463;
# მომხმარებელი 209: მიიღო 413829, განსაზღვრული 365080, სხვაობა 48749;
# მომხმარებელი 210: მიიღო 567264, განსაზღვრული 866021, სხვაობა 298757;
# მომხმარებელი 211: მიიღო 500175, განსაზღვრული 516332, სხვაობა 16157;
# მომხმარებელი 212: მიიღო 579332, განსაზღვრული 950946, სხვაობა 371614;
# მომხმარებელი 213: მიიღო 2658, განსაზღვრული 7466, სხვაობა 4808;
# მომხმარებელი 214: მიიღო 1454, განსაზღვრული 3474, სხვაობა 2020;
# მომხმარებელი 215: მიიღო 366233, განსაზღვრული 440785, სხვაობა 74552;
# მომხმარებელი 216: მიიღო 8155, განსაზღვრული 8897, სხვაობა 742;
# მომხმარებელი 217: მიიღო 158196, განსაზღვრული 243602, სხვაობა 85406;
# მომხმარებელი 218: მიიღო 130896, განსაზღვრული 147667, სხვაობა 16771;
# მომხმარებელი 219: მიიღო 193703, განსაზღვრული 262929, სხვაობა 69226;
# მომხმარებელი 220: მიიღო 17021, განსაზღვრული 45430, სხვაობა 28409;
# მომხმარებელი 221: მიიღო 1978, განსაზღვრული 7596, სხვაობა 5618;
# მომხმარებელი 222: მიიღო 286962, განსაზღვრული 255886, სხვაობა 31076;
# მომხმარებელი 223: მიიღო 89895, განსაზღვრული 173722, სხვაობა 83827;
# მომხმარებელი 224: მიიღო 53174, განსაზღვრული 97450, სხვაობა 44276;
# მომხმარებელი 225: მიიღო 971, განსაზღვრული 3757, სხვაობა 2786;
# მომხმარებელი 226: მიიღო 286425, განსაზღვრული 281744, სხვაობა 4681;
# მომხმარებელი 227: მიიღო 48937, განსაზღვრული 86008, სხვაობა 37071;
# მომხმარებელი 228: მიიღო 236467, განსაზღვრული 229145, სხვაობა 7322;
# მომხმარებელი 229: მიიღო 28365, განსაზღვრული 36301, სხვაობა 7936;
# მომხმარებელი 230: მიიღო 920236, განსაზღვრული 774601, სხვაობა 145635;
# მომხმარებელი 231: მიიღო 163758, განსაზღვრული 211174, სხვაობა 47416;
# მომხმარებელი 232: მიიღო 116619, განსაზღვრული 227317, სხვაობა 110698;
# მომხმარებელი 233: მიიღო 1216564, განსაზღვრული 1006912, სხვაობა 209652;
# მომხმარებელი 234: მიიღო 103591, განსაზღვრული 316749, სხვაობა 213158;
# მომხმარებელი 235: მიიღო 54991, განსაზღვრული 76571, სხვაობა 21580;
# მომხმარებელი 236: მიიღო 247239, განსაზღვრული 322062, სხვაობა 74823;
# მომხმარებელი 237: მიიღო 319350, განსაზღვრული 397410, სხვაობა 78060;
# მომხმარებელი 238: მიიღო 118214, განსაზღვრული 168730, სხვაობა 50516;
# მომხმარებელი 239: მიიღო 1659, განსაზღვრული 5116, სხვაობა 3457;
# მომხმარებელი 240: მიიღო 25448, განსაზღვრული 44878, სხვაობა 19430;
# მომხმარებელი 241: მიიღო 746422, განსაზღვრული 718496, სხვაობა 27926;
# მომხმარებელი 242: მიიღო 76350, განსაზღვრული 106496, სხვაობა 30146;
# მომხმარებელი 243: მიიღო 173456, განსაზღვრული 246254, სხვაობა 72798;
# მომხმარებელი 244: მიიღო 69731, განსაზღვრული 110126, სხვაობა 40395;
# მომხმარებელი 245: მიიღო 192995, განსაზღვრული 282536, სხვაობა 89541;
# მომხმარებელი 246: მიიღო 573495, განსაზღვრული 566800, სხვაობა 6695;
# მომხმარებელი 247: მიიღო 8197, განსაზღვრული 18975, სხვაობა 10778;
# მომხმარებელი 248: მიიღო 28215, განსაზღვრული 42986, სხვაობა 14771;
# მომხმარებელი 249: მიიღო 182423, განსაზღვრული 234526, სხვაობა 52103;
# მომხმარებელი 250: მიიღო 1016, განსაზღვრული 2153, სხვაობა 1137;
# მომხმარებელი 251: მიიღო 124944, განსაზღვრული 219762, სხვაობა 94818;
# მომხმარებელი 252: მიიღო 140527, განსაზღვრული 51132, სხვაობა 89395;
# მომხმარებელი 253: მიიღო 397294, განსაზღვრული 553259, სხვაობა 155965;
# მომხმარებელი 254: მიიღო 1418967, განსაზღვრული 1232819, სხვაობა 186148;
# მომხმარებელი 255: მიიღო 113185, განსაზღვრული 230253, სხვაობა 117068;
# მომხმარებელი 256: მიიღო 109019, განსაზღვრული 194440, სხვაობა 85421;
# მომხმარებელი 257: მიიღო 46182, განსაზღვრული 59682, სხვაობა 13500;
# მომხმარებელი 258: მიიღო 370757, განსაზღვრული 376103, სხვაობა 5346;
# მომხმარებელი 259: მიიღო 18780, განსაზღვრული 42644, სხვაობა 23864;
# მომხმარებელი 260: მიიღო 9818, განსაზღვრული 14158, სხვაობა 4340;
# მომხმარებელი 261: მიიღო 169700, განსაზღვრული 160572, სხვაობა 9128;
# მომხმარებელი 262: მიიღო 131545, განსაზღვრული 194712, სხვაობა 63167;
# მომხმარებელი 263: მიიღო 252881, განსაზღვრული 362974, სხვაობა 110093;
# მომხმარებელი 264: მიიღო 452010, განსაზღვრული 644862, სხვაობა 192852;
# მომხმარებელი 265: მიიღო 33168, განსაზღვრული 45511, სხვაობა 12343;
# მომხმარებელი 266: მიიღო 103370, განსაზღვრული 144825, სხვაობა 41455;
# მომხმარებელი 267: მიიღო 2288, განსაზღვრული 4530, სხვაობა 2242;
# მომხმარებელი 268: მიიღო 283982, განსაზღვრული 302960, სხვაობა 18978;
# მომხმარებელი 269: მიიღო 14143, განსაზღვრული 21088, სხვაობა 6945;
# მომხმარებელი 270: მიიღო 195404, განსაზღვრული 237562, სხვაობა 42158;
# მომხმარებელი 271: მიიღო 50850, განსაზღვრული 81779, სხვაობა 30929;
# მომხმარებელი 272: მიიღო 185037, განსაზღვრული 256551, სხვაობა 71514;
# მომხმარებელი 273: მიიღო 33169, განსაზღვრული 57679, სხვაობა 24510;
# მომხმარებელი 274: მიიღო 7400, განსაზღვრული 18345, სხვაობა 10945;
# მომხმარებელი 275: მიიღო 393047, განსაზღვრული 332427, სხვაობა 60620;
# მომხმარებელი 276: მიიღო 133087, განსაზღვრული 147703, სხვაობა 14616;
# მომხმარებელი 277: მიიღო 13351, განსაზღვრული 19599, სხვაობა 6248;
# მომხმარებელი 278: მიიღო 94472, განსაზღვრული 132490, სხვაობა 38018;
# მომხმარებელი 279: მიიღო 396556, განსაზღვრული 427811, სხვაობა 31255;
# მომხმარებელი 280: მიიღო 71758, განსაზღვრული 112516, სხვაობა 40758;
# მომხმარებელი 281: მიიღო 272136, განსაზღვრული 300378, სხვაობა 28242;
# მომხმარებელი 282: მიიღო 235333, განსაზღვრული 476789, სხვაობა 241456;
# მომხმარებელი 283: მიიღო 98176, განსაზღვრული 159656, სხვაობა 61480;
# მომხმარებელი 284: მიიღო 36504, განსაზღვრული 39991, სხვაობა 3487;
# მომხმარებელი 285: მიიღო 174794, განსაზღვრული 228318, სხვაობა 53524;
# მომხმარებელი 286: მიიღო 540200, განსაზღვრული 625671, სხვაობა 85471;
# მომხმარებელი 287: მიიღო 21837, განსაზღვრული 31245, სხვაობა 9408;
# მომხმარებელი 288: მიიღო 7734, განსაზღვრული 19176, სხვაობა 11442;
# მომხმარებელი 289: მიიღო 15534, განსაზღვრული 30862, სხვაობა 15328;
# მომხმარებელი 290: მიიღო 129465, განსაზღვრული 141042, სხვაობა 11577;
# მომხმარებელი 291: მიიღო 9251, განსაზღვრული 39905, სხვაობა 30654;
# მომხმარებელი 292: მიიღო 217039, განსაზღვრული 235978, სხვაობა 18939;
# მომხმარებელი 293: მიიღო 1976, განსაზღვრული 2031, სხვაობა 55;
# მომხმარებელი 294: მიიღო 82408, განსაზღვრული 113244, სხვაობა 30836;
# მომხმარებელი 295: მიიღო 105682, განსაზღვრული 131588, სხვაობა 25906;
# მომხმარებელი 296: მიიღო 38569, განსაზღვრული 72497, სხვაობა 33928;
# მომხმარებელი 297: მიიღო 4539, განსაზღვრული 27516, სხვაობა 22977;
# მომხმარებელი 298: მიიღო 101494, განსაზღვრული 105528, სხვაობა 4034;
# მომხმარებელი 299: მიიღო 161311, განსაზღვრული 267846, სხვაობა 106535;
# მომხმარებელი 300: მიიღო 646943, განსაზღვრული 608971, სხვაობა 37972;
# მომხმარებელი 301: მიიღო 68892, განსაზღვრული 90075, სხვაობა 21183;
# მომხმარებელი 302: მიიღო 3867, განსაზღვრული 4196, სხვაობა 329;
# მომხმარებელი 303: მიიღო 291751, განსაზღვრული 332492, სხვაობა 40741;
# მომხმარებელი 304: მიიღო 2291, განსაზღვრული 3795, სხვაობა 1504;
# მომხმარებელი 305: მიიღო 51635, განსაზღვრული 47965, სხვაობა 3670;
# მომხმარებელი 306: მიიღო 224360, განსაზღვრული 300107, სხვაობა 75747;
# მომხმარებელი 307: მიიღო 257691, განსაზღვრული 359118, სხვაობა 101427;
# მომხმარებელი 308: მიიღო 15353, განსაზღვრული 17441, სხვაობა 2088;
# მომხმარებელი 309: მიიღო 195857, განსაზღვრული 287384, სხვაობა 91527;
# მომხმარებელი 310: მიიღო 167233, განსაზღვრული 175203, სხვაობა 7970;
# მომხმარებელი 311: მიიღო 93085, განსაზღვრული 83689, სხვაობა 9396;
# მომხმარებელი 312: მიიღო 700658, განსაზღვრული 928895, სხვაობა 228237;
# მომხმარებელი 313: მიიღო 371082, განსაზღვრული 580367, სხვაობა 209285;
# მომხმარებელი 314: მიიღო 404172, განსაზღვრული 333660, სხვაობა 70512;
# მომხმარებელი 315: მიიღო 22341, განსაზღვრული 41745, სხვაობა 19404;
# მომხმარებელი 316: მიიღო 320446, განსაზღვრული 518202, სხვაობა 197756;
# მომხმარებელი 317: მიიღო 85280, განსაზღვრული 118201, სხვაობა 32921;
# მომხმარებელი 318: მიიღო 232764, განსაზღვრული 252839, სხვაობა 20075;
# მომხმარებელი 319: მიიღო 142064, განსაზღვრული 195835, სხვაობა 53771;
# მომხმარებელი 320: მიიღო 34491, განსაზღვრული 65315, სხვაობა 30824;
# მომხმარებელი 321: მიიღო 21121, განსაზღვრული 25562, სხვაობა 4441;
# მომხმარებელი 322: მიიღო 371892, განსაზღვრული 454341, სხვაობა 82449;
# მომხმარებელი 323: მიიღო 11669, განსაზღვრული 18828, სხვაობა 7159;
# მომხმარებელი 324: მიიღო 699147, განსაზღვრული 864548, სხვაობა 165401;
# მომხმარებელი 325: მიიღო 191960, განსაზღვრული 202359, სხვაობა 10399;
# მომხმარებელი 326: მიიღო 50939, განსაზღვრული 67978, სხვაობა 17039;
# მომხმარებელი 327: მიიღო 43983, განსაზღვრული 54059, სხვაობა 10076;
# მომხმარებელი 328: მიიღო 69703, განსაზღვრული 107841, სხვაობა 38138;
# მომხმარებელი 329: მიიღო 25611, განსაზღვრული 25515, სხვაობა 96;
# მომხმარებელი 330: მიიღო 35150, განსაზღვრული 40053, სხვაობა 4903;
# მომხმარებელი 331: მიიღო 264294, განსაზღვრული 321989, სხვაობა 57695;
# მომხმარებელი 332: მიიღო 36249, განსაზღვრული 56988, სხვაობა 20739;
# მომხმარებელი 333: მიიღო 975146, განსაზღვრული 825327, სხვაობა 149819;
# მომხმარებელი 334: მიიღო 335562, განსაზღვრული 494085, სხვაობა 158523;
# მომხმარებელი 335: მიიღო 351597, განსაზღვრული 447446, სხვაობა 95849;
# მომხმარებელი 336: მიიღო 81978, განსაზღვრული 150857, სხვაობა 68879;
# მომხმარებელი 337: მიიღო 108424, განსაზღვრული 235348, სხვაობა 126924;
# მომხმარებელი 338: მიიღო 359946, განსაზღვრული 641833, სხვაობა 281887;
# მომხმარებელი 339: მიიღო 14486, განსაზღვრული 27122, სხვაობა 12636;
# მომხმარებელი 340: მიიღო 273272, განსაზღვრული 396185, სხვაობა 122913;
# მომხმარებელი 341: მიიღო 314131, განსაზღვრული 403383, სხვაობა 89252;
# მომხმარებელი 342: მიიღო 393465, განსაზღვრული 546658, სხვაობა 153193;
# მომხმარებელი 343: მიიღო 2998, განსაზღვრული 11732, სხვაობა 8734;
# მომხმარებელი 344: მიიღო 332084, განსაზღვრული 325337, სხვაობა 6747;
# მომხმარებელი 345: მიიღო 22223, განსაზღვრული 34035, სხვაობა 11812;
# მომხმარებელი 346: მიიღო 195118, განსაზღვრული 309153, სხვაობა 114035;
# მომხმარებელი 347: მიიღო 692, განსაზღვრული 4185, სხვაობა 3493;
# მომხმარებელი 348: მიიღო 18086, განსაზღვრული 30076, სხვაობა 11990;
# მომხმარებელი 349: მიიღო 44100, განსაზღვრული 86009, სხვაობა 41909;
# მომხმარებელი 350: მიიღო 500920, განსაზღვრული 707895, სხვაობა 206975;
# მომხმარებელი 351: მიიღო 323104, განსაზღვრული 555427, სხვაობა 232323;
# მომხმარებელი 352: მიიღო 70149, განსაზღვრული 119168, სხვაობა 49019;
# მომხმარებელი 353: მიიღო 447112, განსაზღვრული 444755, სხვაობა 2357;
# მომხმარებელი 354: მიიღო 241435, განსაზღვრული 276535, სხვაობა 35100;
# მომხმარებელი 355: მიიღო 168842, განსაზღვრული 146054, სხვაობა 22788;
# მომხმარებელი 356: მიიღო 10844, განსაზღვრული 23131, სხვაობა 12287;
# მომხმარებელი 357: მიიღო 532385, განსაზღვრული 696039, სხვაობა 163654;
# მომხმარებელი 358: მიიღო 7098, განსაზღვრული 6813, სხვაობა 285;
# მომხმარებელი 359: მიიღო 336792, განსაზღვრული 333817, სხვაობა 2975;
# მომხმარებელი 360: მიიღო 182, განსაზღვრული 1665, სხვაობა 1483;
# მომხმარებელი 361: მიიღო 272180, განსაზღვრული 456891, სხვაობა 184711;
# მომხმარებელი 362: მიიღო 2497, განსაზღვრული 13992, სხვაობა 11495;
# მომხმარებელი 363: მიიღო 99200, განსაზღვრული 121096, სხვაობა 21896;
# მომხმარებელი 364: მიიღო 760855, განსაზღვრული 816520, სხვაობა 55665;
# მომხმარებელი 365: მიიღო 259047, განსაზღვრული 289164, სხვაობა 30117;
# მომხმარებელი 366: მიიღო 229561, განსაზღვრული 352469, სხვაობა 122908;
# მომხმარებელი 367: მიიღო 2989, განსაზღვრული 8559, სხვაობა 5570;
# მომხმარებელი 368: მიიღო 200579, განსაზღვრული 281473, სხვაობა 80894;
# მომხმარებელი 369: მიიღო 650786, განსაზღვრული 718301, სხვაობა 67515;
# მომხმარებელი 370: მიიღო 803323, განსაზღვრული 672710, სხვაობა 130613;
# მომხმარებელი 371: მიიღო 99778, განსაზღვრული 115452, სხვაობა 15674;
# მომხმარებელი 372: მიიღო 1072, განსაზღვრული 4319, სხვაობა 3247;
# მომხმარებელი 373: მიიღო 2580, განსაზღვრული 5103, სხვაობა 2523;
# მომხმარებელი 374: მიიღო 24863, განსაზღვრული 36568, სხვაობა 11705;
# მომხმარებელი 375: მიიღო 18859, განსაზღვრული 32642, სხვაობა 13783;
# მომხმარებელი 376: მიიღო 47214, განსაზღვრული 59215, სხვაობა 12001;
# მომხმარებელი 377: მიიღო 7793, განსაზღვრული 23485, სხვაობა 15692;
# მომხმარებელი 378: მიიღო 238677, განსაზღვრული 453086, სხვაობა 214409;
# მომხმარებელი 379: მიიღო 2892, განსაზღვრული 4857, სხვაობა 1965;
# მომხმარებელი 380: მიიღო 18782, განსაზღვრული 48898, სხვაობა 30116;
# მომხმარებელი 381: მიიღო 71794, განსაზღვრული 89923, სხვაობა 18129;
# მომხმარებელი 382: მიიღო 57788, განსაზღვრული 113346, სხვაობა 55558;
# მომხმარებელი 383: მიიღო 55608, განსაზღვრული 145387, სხვაობა 89779;
# მომხმარებელი 384: მიიღო 2348, განსაზღვრული 7590, სხვაობა 5242;
# მომხმარებელი 385: მიიღო 40616, განსაზღვრული 52540, სხვაობა 11924;
# მომხმარებელი 386: მიიღო 372421, განსაზღვრული 313641, სხვაობა 58780;
# მომხმარებელი 387: მიიღო 8070, განსაზღვრული 15883, სხვაობა 7813;
# მომხმარებელი 388: მიიღო 365293, განსაზღვრული 364318, სხვაობა 975;
# მომხმარებელი 389: მიიღო 298652, განსაზღვრული 294463, სხვაობა 4189;
# მომხმარებელი 390: მიიღო 780353, განსაზღვრული 809368, სხვაობა 29015;
# მომხმარებელი 391: მიიღო 21806, განსაზღვრული 36530, სხვაობა 14724;
# მომხმარებელი 392: მიიღო 101561, განსაზღვრული 145768, სხვაობა 44207;
# მომხმარებელი 393: მიიღო 19070, განსაზღვრული 18753, სხვაობა 317;
# მომხმარებელი 394: მიიღო 64221, განსაზღვრული 97674, სხვაობა 33453;
# მომხმარებელი 395: მიიღო 659475, განსაზღვრული 703291, სხვაობა 43816;
# მომხმარებელი 396: მიიღო 86247, განსაზღვრული 90592, სხვაობა 4345;
# მომხმარებელი 397: მიიღო 299047, განსაზღვრული 314942, სხვაობა 15895;
# მომხმარებელი 398: მიიღო 418142, განსაზღვრული 372049, სხვაობა 46093;
# მომხმარებელი 399: მიიღო 97706, განსაზღვრული 117575, სხვაობა 19869;
# მომხმარებელი 400: მიიღო 1757, განსაზღვრული 4605, სხვაობა 2848;
# მომხმარებელი 401: მიიღო 4394, განსაზღვრული 8350, სხვაობა 3956;
# მომხმარებელი 402: მიიღო 38829, განსაზღვრული 49175, სხვაობა 10346;
# მომხმარებელი 403: მიიღო 1422, განსაზღვრული 5000, სხვაობა 3578;
# მომხმარებელი 404: მიიღო 184891, განსაზღვრული 250404, სხვაობა 65513;
# მომხმარებელი 405: მიიღო 280518, განსაზღვრული 209487, სხვაობა 71031;
# მომხმარებელი 406: მიიღო 214113, განსაზღვრული 378396, სხვაობა 164283;
# მომხმარებელი 407: მიიღო 5939, განსაზღვრული 8607, სხვაობა 2668;
# მომხმარებელი 408: მიიღო 963703, განსაზღვრული 879807, სხვაობა 83896;
# მომხმარებელი 409: მიიღო 51934, განსაზღვრული 76936, სხვაობა 25002;
# მომხმარებელი 410: მიიღო 188081, განსაზღვრული 270637, სხვაობა 82556;
# მომხმარებელი 411: მიიღო 237699, განსაზღვრული 273055, სხვაობა 35356;
# მომხმარებელი 412: მიიღო 6960, განსაზღვრული 4494, სხვაობა 2466;
# მომხმარებელი 413: მიიღო 482734, განსაზღვრული 481493, სხვაობა 1241;
# მომხმარებელი 414: მიიღო 2821, განსაზღვრული 9513, სხვაობა 6692;
# მომხმარებელი 415: მიიღო 22035, განსაზღვრული 50586, სხვაობა 28551;
# მომხმარებელი 416: მიიღო 166409, განსაზღვრული 163392, სხვაობა 3017;
# მომხმარებელი 417: მიიღო 464870, განსაზღვრული 467156, სხვაობა 2286;
# მომხმარებელი 418: მიიღო 3887, განსაზღვრული 7550, სხვაობა 3663;
# მომხმარებელი 419: მიიღო 703521, განსაზღვრული 824806, სხვაობა 121285;
# მომხმარებელი 420: მიიღო 2503, განსაზღვრული 4237, სხვაობა 1734;
# მომხმარებელი 421: მიიღო 39593, განსაზღვრული 57567, სხვაობა 17974;
# მომხმარებელი 422: მიიღო 95488, განსაზღვრული 84271, სხვაობა 11217;
# მომხმარებელი 423: მიიღო 3902, განსაზღვრული 8260, სხვაობა 4358;
# მომხმარებელი 424: მიიღო 286007, განსაზღვრული 531576, სხვაობა 245569;
# მომხმარებელი 425: მიიღო 11166, განსაზღვრული 13049, სხვაობა 1883;
# მომხმარებელი 426: მიიღო 177689, განსაზღვრული 229618, სხვაობა 51929;
# მომხმარებელი 427: მიიღო 23744, განსაზღვრული 38899, სხვაობა 15155;
# მომხმარებელი 428: მიიღო 62463, განსაზღვრული 110666, სხვაობა 48203;
# მომხმარებელი 429: მიიღო 581417, განსაზღვრული 624943, სხვაობა 43526;
# მომხმარებელი 430: მიიღო 735745, განსაზღვრული 780455, სხვაობა 44710;
# მომხმარებელი 431: მიიღო 15272, განსაზღვრული 15339, სხვაობა 67;
# მომხმარებელი 432: მიიღო 373820, განსაზღვრული 466888, სხვაობა 93068;
# მომხმარებელი 433: მიიღო 68711, განსაზღვრული 138431, სხვაობა 69720;
# მომხმარებელი 434: მიიღო 29351, განსაზღვრული 35225, სხვაობა 5874;
# მომხმარებელი 435: მიიღო 7281, განსაზღვრული 13797, სხვაობა 6516;
# მომხმარებელი 436: მიიღო 202671, განსაზღვრული 297880, სხვაობა 95209;
# მომხმარებელი 437: მიიღო 5461, განსაზღვრული 9909, სხვაობა 4448;
# მომხმარებელი 438: მიიღო 169831, განსაზღვრული 173407, სხვაობა 3576;
# მომხმარებელი 439: მიიღო 453685, განსაზღვრული 582867, სხვაობა 129182;
# მომხმარებელი 440: მიიღო 644162, განსაზღვრული 654324, სხვაობა 10162;
# მომხმარებელი 441: მიიღო 12885, განსაზღვრული 38539, სხვაობა 25654;
# მომხმარებელი 442: მიიღო 7264, განსაზღვრული 8562, სხვაობა 1298;
# მომხმარებელი 443: მიიღო 2549, განსაზღვრული 3795, სხვაობა 1246;
# მომხმარებელი 444: მიიღო 61435, განსაზღვრული 146443, სხვაობა 85008;
# მომხმარებელი 445: მიიღო 94788, განსაზღვრული 187917, სხვაობა 93129;
# მომხმარებელი 446: მიიღო 379984, განსაზღვრული 415046, სხვაობა 35062;
# მომხმარებელი 447: მიიღო 3854, განსაზღვრული 3983, სხვაობა 129;
# მომხმარებელი 448: მიიღო 160491, განსაზღვრული 534631, სხვაობა 374140;
# მომხმარებელი 449: მიიღო 59690, განსაზღვრული 103560, სხვაობა 43870;
# მომხმარებელი 450: მიიღო 8418, განსაზღვრული 11610, სხვაობა 3192;
# მომხმარებელი 451: მიიღო 429056, განსაზღვრული 661126, სხვაობა 232070;
# მომხმარებელი 452: მიიღო 139776, განსაზღვრული 245808, სხვაობა 106032;
# მომხმარებელი 453: მიიღო 48563, განსაზღვრული 78917, სხვაობა 30354;
# მომხმარებელი 454: მიიღო 106485, განსაზღვრული 165037, სხვაობა 58552;
# მომხმარებელი 455: მიიღო 27831, განსაზღვრული 45858, სხვაობა 18027;
# მომხმარებელი 456: მიიღო 60929, განსაზღვრული 138707, სხვაობა 77778;
# მომხმარებელი 457: მიიღო 40454, განსაზღვრული 87333, სხვაობა 46879;
# მომხმარებელი 458: მიიღო 37028, განსაზღვრული 61386, სხვაობა 24358;
# მომხმარებელი 459: მიიღო 348556, განსაზღვრული 588348, სხვაობა 239792;
# მომხმარებელი 460: მიიღო 196312, განსაზღვრული 256850, სხვაობა 60538;
# მომხმარებელი 461: მიიღო 86173, განსაზღვრული 121805, სხვაობა 35632;
# მომხმარებელი 462: მიიღო 497788, განსაზღვრული 621402, სხვაობა 123614;
# მომხმარებელი 463: მიიღო 303791, განსაზღვრული 460084, სხვაობა 156293;
# მომხმარებელი 464: მიიღო 32275, განსაზღვრული 24196, სხვაობა 8079;
# მომხმარებელი 465: მიიღო 123128, განსაზღვრული 150926, სხვაობა 27798;
# მომხმარებელი 466: მიიღო 164168, განსაზღვრული 279858, სხვაობა 115690;
# მომხმარებელი 467: მიიღო 3892, განსაზღვრული 12827, სხვაობა 8935;
# მომხმარებელი 468: მიიღო 140297, განსაზღვრული 290348, სხვაობა 150051;
# მომხმარებელი 469: მიიღო 14622, განსაზღვრული 39719, სხვაობა 25097;
# მომხმარებელი 470: მიიღო 181503, განსაზღვრული 584274, სხვაობა 402771;
# მომხმარებელი 471: მიიღო 64482, განსაზღვრული 115540, სხვაობა 51058;
# მომხმარებელი 472: მიიღო 105056, განსაზღვრული 117235, სხვაობა 12179;
# მომხმარებელი 473: მიიღო 314731, განსაზღვრული 413922, სხვაობა 99191;
# მომხმარებელი 474: მიიღო 101726, განსაზღვრული 95130, სხვაობა 6596;
# მომხმარებელი 475: მიიღო 665921, განსაზღვრული 1045792, სხვაობა 379871;
# მომხმარებელი 476: მიიღო 559681, განსაზღვრული 634277, სხვაობა 74596;
# მომხმარებელი 477: მიიღო 67893, განსაზღვრული 166413, სხვაობა 98520;
# მომხმარებელი 478: მიიღო 248201, განსაზღვრული 249183, სხვაობა 982;
# მომხმარებელი 479: მიიღო 881814, განსაზღვრული 840410, სხვაობა 41404;
# მომხმარებელი 480: მიიღო 141487, განსაზღვრული 195293, სხვაობა 53806;
# მომხმარებელი 481: მიიღო 194135, განსაზღვრული 328643, სხვაობა 134508;
# მომხმარებელი 482: მიიღო 41412, განსაზღვრული 78562, სხვაობა 37150;
# მომხმარებელი 483: მიიღო 54606, განსაზღვრული 66188, სხვაობა 11582;
# მომხმარებელი 484: მიიღო 210076, განსაზღვრული 253424, სხვაობა 43348;
# მომხმარებელი 485: მიიღო 201999, განსაზღვრული 255082, სხვაობა 53083;
# მომხმარებელი 486: მიიღო 13843, განსაზღვრული 19011, სხვაობა 5168;
# მომხმარებელი 487: მიიღო 74066, განსაზღვრული 114899, სხვაობა 40833;
# მომხმარებელი 488: მიიღო 204923, განსაზღვრული 180090, სხვაობა 24833;
# მომხმარებელი 489: მიიღო 10468, განსაზღვრული 17606, სხვაობა 7138;
# მომხმარებელი 490: მიიღო 9404, განსაზღვრული 18758, სხვაობა 9354;
# მომხმარებელი 491: მიიღო 271806, განსაზღვრული 293572, სხვაობა 21766;
# მომხმარებელი 492: მიიღო 99809, განსაზღვრული 190425, სხვაობა 90616;
# მომხმარებელი 493: მიიღო 80905, განსაზღვრული 100741, სხვაობა 19836;
# მომხმარებელი 494: მიიღო 217170, განსაზღვრული 307445, სხვაობა 90275;
# მომხმარებელი 495: მიიღო 205764, განსაზღვრული 275860, სხვაობა 70096;
# მომხმარებელი 496: მიიღო 205011, განსაზღვრული 220477, სხვაობა 15466;
# მომხმარებელი 497: მიიღო 48544, განსაზღვრული 82053, სხვაობა 33509;
# მომხმარებელი 498: მიიღო 28069, განსაზღვრული 61676, სხვაობა 33607;
# მომხმარებელი 499: მიიღო 16165, განსაზღვრული 45510, სხვაობა 29345;
# მომხმარებელი 500: მიიღო 348580, განსაზღვრული 534054, სხვაობა 185474;
# მომხმარებელი 501: მიიღო 957439, განსაზღვრული 801966, სხვაობა 155473;
# მომხმარებელი 502: მიიღო 718385, განსაზღვრული 845801, სხვაობა 127416;
# მომხმარებელი 503: მიიღო 26490, განსაზღვრული 35744, სხვაობა 9254;
# მომხმარებელი 504: მიიღო 39488, განსაზღვრული 50334, სხვაობა 10846;
# მომხმარებელი 505: მიიღო 59450, განსაზღვრული 71843, სხვაობა 12393;
# მომხმარებელი 506: მიიღო 46268, განსაზღვრული 58112, სხვაობა 11844;
# მომხმარებელი 507: მიიღო 243557, განსაზღვრული 382926, სხვაობა 139369;
# მომხმარებელი 508: მიიღო 2787, განსაზღვრული 3850, სხვაობა 1063;
# მომხმარებელი 509: მიიღო 67817, განსაზღვრული 89285, სხვაობა 21468;
# მომხმარებელი 510: მიიღო 377284, განსაზღვრული 569517, სხვაობა 192233;
# მომხმარებელი 511: მიიღო 404924, განსაზღვრული 418737, სხვაობა 13813;
# მომხმარებელი 512: მიიღო 1430781, განსაზღვრული 1115645, სხვაობა 315136;
# მომხმარებელი 513: მიიღო 5517, განსაზღვრული 21524, სხვაობა 16007;
# მომხმარებელი 514: მიიღო 14604, განსაზღვრული 34163, სხვაობა 19559;
# მომხმარებელი 515: მიიღო 161, განსაზღვრული 3795, სხვაობა 3634;
# მომხმარებელი 516: მიიღო 6620, განსაზღვრული 8662, სხვაობა 2042;
# მომხმარებელი 517: მიიღო 101528, განსაზღვრული 144852, სხვაობა 43324;
# მომხმარებელი 518: მიიღო 726483, განსაზღვრული 680878, სხვაობა 45605;
# მომხმარებელი 519: მიიღო 85544, განსაზღვრული 189268, სხვაობა 103724;
# მომხმარებელი 520: მიიღო 37694, განსაზღვრული 49606, სხვაობა 11912;
# მომხმარებელი 521: მიიღო 29374, განსაზღვრული 71095, სხვაობა 41721;
# მომხმარებელი 522: მიიღო 333686, განსაზღვრული 350831, სხვაობა 17145;
# მომხმარებელი 523: მიიღო 390547, განსაზღვრული 576254, სხვაობა 185707;
# მომხმარებელი 524: მიიღო 52014, განსაზღვრული 78842, სხვაობა 26828;
# მომხმარებელი 525: მიიღო 116396, განსაზღვრული 137830, სხვაობა 21434;
# მომხმარებელი 526: მიიღო 6404, განსაზღვრული 31995, სხვაობა 25591;
# მომხმარებელი 527: მიიღო 668643, განსაზღვრული 563054, სხვაობა 105589;
# მომხმარებელი 528: მიიღო 431902, განსაზღვრული 615400, სხვაობა 183498;
# მომხმარებელი 529: მიიღო 391254, განსაზღვრული 717482, სხვაობა 326228;
# მომხმარებელი 530: მიიღო 254275, განსაზღვრული 261916, სხვაობა 7641;
# მომხმარებელი 531: მიიღო 30239, განსაზღვრული 52482, სხვაობა 22243;
# მომხმარებელი 532: მიიღო 294445, განსაზღვრული 355291, სხვაობა 60846;
# მომხმარებელი 533: მიიღო 68185, განსაზღვრული 161632, სხვაობა 93447;
# მომხმარებელი 534: მიიღო 141929, განსაზღვრული 191537, სხვაობა 49608;
# მომხმარებელი 535: მიიღო 205979, განსაზღვრული 356464, სხვაობა 150485;
# მომხმარებელი 536: მიიღო 204270, განსაზღვრული 223699, სხვაობა 19429;
# მომხმარებელი 537: მიიღო 121040, განსაზღვრული 163196, სხვაობა 42156;
# მომხმარებელი 538: მიიღო 190772, განსაზღვრული 351350, სხვაობა 160578;
# მომხმარებელი 539: მიიღო 146010, განსაზღვრული 229815, სხვაობა 83805;
# მომხმარებელი 540: მიიღო 93757, განსაზღვრული 113609, სხვაობა 19852;
# მომხმარებელი 541: მიიღო 202514, განსაზღვრული 272719, სხვაობა 70205;
# მომხმარებელი 542: მიიღო 151427, განსაზღვრული 172738, სხვაობა 21311;
# მომხმარებელი 543: მიიღო 756586, განსაზღვრული 695697, სხვაობა 60889;
# მომხმარებელი 544: მიიღო 318631, განსაზღვრული 390762, სხვაობა 72131;
# მომხმარებელი 545: მიიღო 250076, განსაზღვრული 324390, სხვაობა 74314;
# მომხმარებელი 546: მიიღო 409414, განსაზღვრული 410182, სხვაობა 768;
# მომხმარებელი 547: მიიღო 214983, განსაზღვრული 359253, სხვაობა 144270;
# მომხმარებელი 548: მიიღო 28799, განსაზღვრული 49441, სხვაობა 20642;
# მომხმარებელი 549: მიიღო 440187, განსაზღვრული 529729, სხვაობა 89542;
# მომხმარებელი 550: მიიღო 559968, განსაზღვრული 800359, სხვაობა 240391;
# მომხმარებელი 551: მიიღო 28811, განსაზღვრული 31903, სხვაობა 3092;
# მომხმარებელი 552: მიიღო 226290, განსაზღვრული 571821, სხვაობა 345531;
# მომხმარებელი 553: მიიღო 92931, განსაზღვრული 130249, სხვაობა 37318;
# მომხმარებელი 554: მიიღო 60044, განსაზღვრული 90417, სხვაობა 30373;
# მომხმარებელი 555: მიიღო 144085, განსაზღვრული 188746, სხვაობა 44661;
# მომხმარებელი 556: მიიღო 275029, განსაზღვრული 389439, სხვაობა 114410;
# მომხმარებელი 557: მიიღო 20446, განსაზღვრული 34348, სხვაობა 13902;
# მომხმარებელი 558: მიიღო 15250, განსაზღვრული 20652, სხვაობა 5402;
# მომხმარებელი 559: მიიღო 61890, განსაზღვრული 119885, სხვაობა 57995;
# მომხმარებელი 560: მიიღო 5251, განსაზღვრული 10168, სხვაობა 4917;
# მომხმარებელი 561: მიიღო 242728, განსაზღვრული 328305, სხვაობა 85577;
# მომხმარებელი 562: მიიღო 260723, განსაზღვრული 306499, სხვაობა 45776;
# მომხმარებელი 563: მიიღო 42084, განსაზღვრული 70962, სხვაობა 28878;
# მომხმარებელი 564: მიიღო 136448, განსაზღვრული 225163, სხვაობა 88715;
# მომხმარებელი 565: მიიღო 14536, განსაზღვრული 21785, სხვაობა 7249;
# მომხმარებელი 566: მიიღო 31792, განსაზღვრული 62384, სხვაობა 30592;
# მომხმარებელი 567: მიიღო 113141, განსაზღვრული 188206, სხვაობა 75065;
# მომხმარებელი 568: მიიღო 605594, განსაზღვრული 774661, სხვაობა 169067;
# მომხმარებელი 569: მიიღო 91883, განსაზღვრული 119511, სხვაობა 27628;
# მომხმარებელი 570: მიიღო 86559, განსაზღვრული 107943, სხვაობა 21384;
# მომხმარებელი 571: მიიღო 133867, განსაზღვრული 182197, სხვაობა 48330;
# მომხმარებელი 572: მიიღო 57146, განსაზღვრული 107230, სხვაობა 50084;
# მომხმარებელი 573: მიიღო 1425, განსაზღვრული 1537, სხვაობა 112;
# მომხმარებელი 574: მიიღო 617596, განსაზღვრული 813841, სხვაობა 196245;
# მომხმარებელი 575: მიიღო 314832, განსაზღვრული 366233, სხვაობა 51401;
# მომხმარებელი 576: მიიღო 63731, განსაზღვრული 87764, სხვაობა 24033;
# მომხმარებელი 577: მიიღო 351870, განსაზღვრული 351820, სხვაობა 50;
# მომხმარებელი 578: მიიღო 110439, განსაზღვრული 158135, სხვაობა 47696;
# მომხმარებელი 579: მიიღო 6150, განსაზღვრული 12361, სხვაობა 6211;
# მომხმარებელი 580: მიიღო 2918, განსაზღვრული 5513, სხვაობა 2595;
# მომხმარებელი 581: მიიღო 143014, განსაზღვრული 274621, სხვაობა 131607;
# მომხმარებელი 582: მიიღო 163042, განსაზღვრული 388511, სხვაობა 225469;
# მომხმარებელი 583: მიიღო 25274, განსაზღვრული 63689, სხვაობა 38415;
# მომხმარებელი 584: მიიღო 121016, განსაზღვრული 246898, სხვაობა 125882;
# მომხმარებელი 585: მიიღო 312, განსაზღვრული 4221, სხვაობა 3909;
# მომხმარებელი 586: მიიღო 33982, განსაზღვრული 30495, სხვაობა 3487;
# მომხმარებელი 587: მიიღო 2321, განსაზღვრული 5216, სხვაობა 2895;
# მომხმარებელი 588: მიიღო 119363, განსაზღვრული 206075, სხვაობა 86712;
# მომხმარებელი 589: მიიღო 116844, განსაზღვრული 128260, სხვაობა 11416;
# მომხმარებელი 590: მიიღო 26364, განსაზღვრული 32563, სხვაობა 6199;
# მომხმარებელი 591: მიიღო 8054, განსაზღვრული 22286, სხვაობა 14232;
# მომხმარებელი 592: მიიღო 293445, განსაზღვრული 331332, სხვაობა 37887;
# მომხმარებელი 593: მიიღო 308345, განსაზღვრული 450491, სხვაობა 142146;
# მომხმარებელი 594: მიიღო 4658, განსაზღვრული 4933, სხვაობა 275;
# მომხმარებელი 595: მიიღო 255832, განსაზღვრული 266717, სხვაობა 10885;
# მომხმარებელი 596: მიიღო 133073, განსაზღვრული 148851, სხვაობა 15778;
# მომხმარებელი 597: მიიღო 113018, განსაზღვრული 136357, სხვაობა 23339;
# მომხმარებელი 598: მიიღო 77701, განსაზღვრული 177810, სხვაობა 100109;
# მომხმარებელი 599: მიიღო 160786, განსაზღვრული 300396, სხვაობა 139610;
# მომხმარებელი 600: მიიღო 6528, განსაზღვრული 13856, სხვაობა 7328;
# მომხმარებელი 601: მიიღო 16308, განსაზღვრული 27324, სხვაობა 11016;
# მომხმარებელი 602: მიიღო 391664, განსაზღვრული 313381, სხვაობა 78283;
# მომხმარებელი 603: მიიღო 2427, განსაზღვრული 8508, სხვაობა 6081;
# მომხმარებელი 604: მიიღო 82073, განსაზღვრული 85960, სხვაობა 3887;
# მომხმარებელი 605: მიიღო 3375, განსაზღვრული 8880, სხვაობა 5505;
# მომხმარებელი 606: მიიღო 630831, განსაზღვრული 831610, სხვაობა 200779;
# მომხმარებელი 607: მიიღო 160343, განსაზღვრული 345739, სხვაობა 185396;
# მომხმარებელი 608: მიიღო 97780, განსაზღვრული 137328, სხვაობა 39548;
# მომხმარებელი 609: მიიღო 21535, განსაზღვრული 51605, სხვაობა 30070;
# მომხმარებელი 610: მიიღო 243173, განსაზღვრული 283201, სხვაობა 40028;
# მომხმარებელი 611: მიიღო 228, განსაზღვრული 4007, სხვაობა 3779;
# მომხმარებელი 612: მიიღო 284, განსაზღვრული 2130, სხვაობა 1846;
# მომხმარებელი 613: მიიღო 90973, განსაზღვრული 155474, სხვაობა 64501;
# მომხმარებელი 614: მიიღო 73357, განსაზღვრული 98435, სხვაობა 25078;
# მომხმარებელი 615: მიიღო 123665, განსაზღვრული 305127, სხვაობა 181462;
# მომხმარებელი 616: მიიღო 744, განსაზღვრული 3883, სხვაობა 3139;
# მომხმარებელი 617: მიიღო 158234, განსაზღვრული 201917, სხვაობა 43683;
# მომხმარებელი 618: მიიღო 24794, განსაზღვრული 58383, სხვაობა 33589;
# მომხმარებელი 619: მიიღო 377291, განსაზღვრული 470478, სხვაობა 93187;
# მომხმარებელი 620: მიიღო 60688, განსაზღვრული 93320, სხვაობა 32632;
# მომხმარებელი 621: მიიღო 193380, განსაზღვრული 295197, სხვაობა 101817;
# მომხმარებელი 622: მიიღო 191436, განსაზღვრული 206395, სხვაობა 14959;
# მომხმარებელი 623: მიიღო 24257, განსაზღვრული 38326, სხვაობა 14069;
# მომხმარებელი 624: მიიღო 245270, განსაზღვრული 309716, სხვაობა 64446;
# მომხმარებელი 625: მიიღო 431798, განსაზღვრული 480448, სხვაობა 48650;
# მომხმარებელი 626: მიიღო 45950, განსაზღვრული 108137, სხვაობა 62187;
# მომხმარებელი 627: მიიღო 15941, განსაზღვრული 20219, სხვაობა 4278;
# მომხმარებელი 628: მიიღო 145020, განსაზღვრული 253154, სხვაობა 108134;
# მომხმარებელი 629: მიიღო 34295, განსაზღვრული 51292, სხვაობა 16997;
# მომხმარებელი 630: მიიღო 64257, განსაზღვრული 77519, სხვაობა 13262;
# მომხმარებელი 631: მიიღო 342637, განსაზღვრული 677705, სხვაობა 335068;
# მომხმარებელი 632: მიიღო 95915, განსაზღვრული 166124, სხვაობა 70209;
# მომხმარებელი 633: მიიღო 747400, განსაზღვრული 849344, სხვაობა 101944;
# მომხმარებელი 634: მიიღო 292890, განსაზღვრული 397996, სხვაობა 105106;
# მომხმარებელი 635: მიიღო 500654, განსაზღვრული 429249, სხვაობა 71405;
# მომხმარებელი 636: მიიღო 378488, განსაზღვრული 373159, სხვაობა 5329;
# მომხმარებელი 637: მიიღო 213863, განსაზღვრული 310999, სხვაობა 97136;
# მომხმარებელი 638: მიიღო 148185, განსაზღვრული 167475, სხვაობა 19290;
# მომხმარებელი 639: მიიღო 133238, განსაზღვრული 205423, სხვაობა 72185;
# მომხმარებელი 640: მიიღო 436853, განსაზღვრული 427228, სხვაობა 9625;
# მომხმარებელი 641: მიიღო 79976, განსაზღვრული 102687, სხვაობა 22711;
# მომხმარებელი 642: მიიღო 360990, განსაზღვრული 535143, სხვაობა 174153;
# მომხმარებელი 643: მიიღო 6600, განსაზღვრული 7828, სხვაობა 1228;
# მომხმარებელი 644: მიიღო 2197, განსაზღვრული 4500, სხვაობა 2303;
# მომხმარებელი 645: მიიღო 286629, განსაზღვრული 289394, სხვაობა 2765;
# მომხმარებელი 646: მიიღო 167793, განსაზღვრული 226813, სხვაობა 59020;
# მომხმარებელი 647: მიიღო 105774, განსაზღვრული 125876, სხვაობა 20102;
# მომხმარებელი 648: მიიღო 642708, განსაზღვრული 572759, სხვაობა 69949;
# მომხმარებელი 649: მიიღო 705585, განსაზღვრული 848545, სხვაობა 142960;
# მომხმარებელი 650: მიიღო 180057, განსაზღვრული 295393, სხვაობა 115336;
# მომხმარებელი 651: მიიღო 5678, განსაზღვრული 12303, სხვაობა 6625;
# მომხმარებელი 652: მიიღო 653478, განსაზღვრული 741931, სხვაობა 88453;
# მომხმარებელი 653: მიიღო 27189, განსაზღვრული 52205, სხვაობა 25016;
# მომხმარებელი 654: მიიღო 92, განსაზღვრული 1575, სხვაობა 1483;
# მომხმარებელი 655: მიიღო 831, განსაზღვრული 3968, სხვაობა 3137;
# მომხმარებელი 656: მიიღო 1020, განსაზღვრული 4312, სხვაობა 3292;
# მომხმარებელი 657: მიიღო 158296, განსაზღვრული 201404, სხვაობა 43108;
# მომხმარებელი 658: მიიღო 151450, განსაზღვრული 262526, სხვაობა 111076;
# მომხმარებელი 659: მიიღო 296375, განსაზღვრული 257335, სხვაობა 39040;
# მომხმარებელი 660: მიიღო 936, განსაზღვრული 3993, სხვაობა 3057;
# მომხმარებელი 661: მიიღო 106151, განსაზღვრული 136757, სხვაობა 30606;
# მომხმარებელი 662: მიიღო 55561, განსაზღვრული 99536, სხვაობა 43975;
# მომხმარებელი 663: მიიღო 46883, განსაზღვრული 59357, სხვაობა 12474;
# მომხმარებელი 664: მიიღო 433251, განსაზღვრული 480211, სხვაობა 46960;
# მომხმარებელი 665: მიიღო 113574, განსაზღვრული 131609, სხვაობა 18035;
# მომხმარებელი 666: მიიღო 388454, განსაზღვრული 416274, სხვაობა 27820;
# მომხმარებელი 667: მიიღო 434856, განსაზღვრული 416134, სხვაობა 18722;
# მომხმარებელი 668: მიიღო 398985, განსაზღვრული 483377, სხვაობა 84392;
# მომხმარებელი 669: მიიღო 45259, განსაზღვრული 115176, სხვაობა 69917;
# მომხმარებელი 670: მიიღო 1072071, განსაზღვრული 769680, სხვაობა 302391;
# მომხმარებელი 671: მიიღო 66897, განსაზღვრული 74193, სხვაობა 7296;
# მომხმარებელი 672: მიიღო 387315, განსაზღვრული 724242, სხვაობა 336927;
# მომხმარებელი 673: მიიღო 45623, განსაზღვრული 43588, სხვაობა 2035;
# მომხმარებელი 674: მიიღო 312404, განსაზღვრული 384629, სხვაობა 72225;
# მომხმარებელი 675: მიიღო 84452, განსაზღვრული 103128, სხვაობა 18676;
# მომხმარებელი 676: მიიღო 328487, განსაზღვრული 333024, სხვაობა 4537;
# მომხმარებელი 677: მიიღო 25418, განსაზღვრული 51543, სხვაობა 26125;
# მომხმარებელი 678: მიიღო 341231, განსაზღვრული 355629, სხვაობა 14398;
# მომხმარებელი 679: მიიღო 110325, განსაზღვრული 112436, სხვაობა 2111;
# მომხმარებელი 680: მიიღო 2739, განსაზღვრული 4294, სხვაობა 1555;
# მომხმარებელი 681: მიიღო 7633, განსაზღვრული 15180, სხვაობა 7547;
# მომხმარებელი 682: მიიღო 11789, განსაზღვრული 49506, სხვაობა 37717;
# მომხმარებელი 683: მიიღო 27914, განსაზღვრული 37279, სხვაობა 9365;
# მომხმარებელი 684: მიიღო 135813, განსაზღვრული 331867, სხვაობა 196054;
# მომხმარებელი 685: მიიღო 27896, განსაზღვრული 45030, სხვაობა 17134;
# მომხმარებელი 686: მიიღო 910, განსაზღვრული 1819, სხვაობა 909;
# მომხმარებელი 687: მიიღო 262579, განსაზღვრული 475049, სხვაობა 212470;
# მომხმარებელი 688: მიიღო 262307, განსაზღვრული 444566, სხვაობა 182259;
# მომხმარებელი 689: მიიღო 81296, განსაზღვრული 200637, სხვაობა 119341;
# მომხმარებელი 690: მიიღო 183436, განსაზღვრული 189502, სხვაობა 6066;
# მომხმარებელი 691: მიიღო 2413, განსაზღვრული 11337, სხვაობა 8924;
# მომხმარებელი 692: მიიღო 341476, განსაზღვრული 381038, სხვაობა 39562;
# მომხმარებელი 693: მიიღო 12640, განსაზღვრული 42013, სხვაობა 29373;
# მომხმარებელი 694: მიიღო 52639, განსაზღვრული 106110, სხვაობა 53471;
# მომხმარებელი 695: მიიღო 606650, განსაზღვრული 639160, სხვაობა 32510;
# მომხმარებელი 696: მიიღო 36494, განსაზღვრული 35816, სხვაობა 678;
# მომხმარებელი 697: მიიღო 630, განსაზღვრული 7235, სხვაობა 6605;
# მომხმარებელი 698: მიიღო 379566, განსაზღვრული 410398, სხვაობა 30832;
# მომხმარებელი 699: მიიღო 71877, განსაზღვრული 77980, სხვაობა 6103;
# მომხმარებელი 700: მიიღო 255439, განსაზღვრული 389894, სხვაობა 134455;
# მომხმარებელი 701: მიიღო 6072, განსაზღვრული 9555, სხვაობა 3483;
# მომხმარებელი 702: მიიღო 6146, განსაზღვრული 10089, სხვაობა 3943;
# მომხმარებელი 703: მიიღო 73107, განსაზღვრული 108183, სხვაობა 35076;
# მომხმარებელი 704: მიიღო 55521, განსაზღვრული 45281, სხვაობა 10240;
# მომხმარებელი 705: მიიღო 50276, განსაზღვრული 70608, სხვაობა 20332;
# მომხმარებელი 706: მიიღო 63947, განსაზღვრული 68227, სხვაობა 4280;
# მომხმარებელი 707: მიიღო 908762, განსაზღვრული 725433, სხვაობა 183329;
# მომხმარებელი 708: მიიღო 87742, განსაზღვრული 114589, სხვაობა 26847;
# მომხმარებელი 709: მიიღო 6266, განსაზღვრული 12705, სხვაობა 6439;
# მომხმარებელი 710: მიიღო 23717, განსაზღვრული 25170, სხვაობა 1453;
# მომხმარებელი 711: მიიღო 21144, განსაზღვრული 35536, სხვაობა 14392;
# მომხმარებელი 712: მიიღო 35579, განსაზღვრული 56354, სხვაობა 20775;
# მომხმარებელი 713: მიიღო 37456, განსაზღვრული 79428, სხვაობა 41972;
# მომხმარებელი 714: მიიღო 727147, განსაზღვრული 742278, სხვაობა 15131;
# მომხმარებელი 715: მიიღო 2417, განსაზღვრული 5865, სხვაობა 3448;
# მომხმარებელი 716: მიიღო 345366, განსაზღვრული 709606, სხვაობა 364240;
# მომხმარებელი 717: მიიღო 851962, განსაზღვრული 1244489, სხვაობა 392527;
# მომხმარებელი 718: მიიღო 58700, განსაზღვრული 80951, სხვაობა 22251;
# მომხმარებელი 719: მიიღო 8238, განსაზღვრული 24695, სხვაობა 16457;
# მომხმარებელი 720: მიიღო 468776, განსაზღვრული 498687, სხვაობა 29911;
# ...
# მომხმარებელი 9662: მიიღო 218416, განსაზღვრული 480265, სხვაობა 261849;
# მომხმარებელი 9663: მიიღო 54360, განსაზღვრული 127278, სხვაობა 72918;
# მომხმარებელი 9664: მიიღო 140858, განსაზღვრული 142003, სხვაობა 1145;
# მომხმარებელი 9665: მიიღო 512, განსაზღვრული 2203, სხვაობა 1691;
# მომხმარებელი 9666: მიიღო 15536, განსაზღვრული 21675, სხვაობა 6139;
# მომხმარებელი 9667: მიიღო 24639, განსაზღვრული 48528, სხვაობა 23889;
# მომხმარებელი 9668: მიიღო 494939, განსაზღვრული 564874, სხვაობა 69935;
# მომხმარებელი 9669: მიიღო 4477, განსაზღვრული 8644, სხვაობა 4167;
# მომხმარებელი 9670: მიიღო 206156, განსაზღვრული 312739, სხვაობა 106583;
# მომხმარებელი 9671: მიიღო 167024, განსაზღვრული 161818, სხვაობა 5206;
# მომხმარებელი 9672: მიიღო 286135, განსაზღვრული 309588, სხვაობა 23453;
# მომხმარებელი 9673: მიიღო 104657, განსაზღვრული 179755, სხვაობა 75098;
# მომხმარებელი 9674: მიიღო 129561, განსაზღვრული 151658, სხვაობა 22097;
# მომხმარებელი 9675: მიიღო 115766, განსაზღვრული 150940, სხვაობა 35174;
# მომხმარებელი 9676: მიიღო 15938, განსაზღვრული 37260, სხვაობა 21322;
# მომხმარებელი 9677: მიიღო 361187, განსაზღვრული 445030, სხვაობა 83843;
# მომხმარებელი 9678: მიიღო 26908, განსაზღვრული 43851, სხვაობა 16943;
# მომხმარებელი 9679: მიიღო 337585, განსაზღვრული 370019, სხვაობა 32434;
# მომხმარებელი 9680: მიიღო 344940, განსაზღვრული 523673, სხვაობა 178733;
# მომხმარებელი 9681: მიიღო 405665, განსაზღვრული 430007, სხვაობა 24342;
# მომხმარებელი 9682: მიიღო 32797, განსაზღვრული 33345, სხვაობა 548;
# მომხმარებელი 9683: მიიღო 224601, განსაზღვრული 458286, სხვაობა 233685;
# მომხმარებელი 9684: მიიღო 404608, განსაზღვრული 482524, სხვაობა 77916;
# მომხმარებელი 9685: მიიღო 1052, განსაზღვრული 5054, სხვაობა 4002;
# მომხმარებელი 9686: მიიღო 332321, განსაზღვრული 362666, სხვაობა 30345;
# მომხმარებელი 9687: მიიღო 117726, განსაზღვრული 97845, სხვაობა 19881;
# მომხმარებელი 9688: მიიღო 3785, განსაზღვრული 13475, სხვაობა 9690;
# მომხმარებელი 9689: მიიღო 79763, განსაზღვრული 88774, სხვაობა 9011;
# მომხმარებელი 9690: მიიღო 102521, განსაზღვრული 167395, სხვაობა 64874;
# მომხმარებელი 9691: მიიღო 45975, განსაზღვრული 56481, სხვაობა 10506;
# მომხმარებელი 9692: მიიღო 113570, განსაზღვრული 121296, სხვაობა 7726;
# მომხმარებელი 9693: მიიღო 356856, განსაზღვრული 385396, სხვაობა 28540;
# მომხმარებელი 9694: მიიღო 487092, განსაზღვრული 454192, სხვაობა 32900;
# მომხმარებელი 9695: მიიღო 30570, განსაზღვრული 49113, სხვაობა 18543;
# მომხმარებელი 9696: მიიღო 180810, განსაზღვრული 277984, სხვაობა 97174;
# მომხმარებელი 9697: მიიღო 579379, განსაზღვრული 450871, სხვაობა 128508;
# მომხმარებელი 9698: მიიღო 41527, განსაზღვრული 61554, სხვაობა 20027;
# მომხმარებელი 9699: მიიღო 31726, განსაზღვრული 41745, სხვაობა 10019;
# მომხმარებელი 9700: მიიღო 11256, განსაზღვრული 13989, სხვაობა 2733;
# მომხმარებელი 9701: მიიღო 102579, განსაზღვრული 141581, სხვაობა 39002;
# მომხმარებელი 9702: მიიღო 865505, განსაზღვრული 1136753, სხვაობა 271248;
# მომხმარებელი 9703: მიიღო 630164, განსაზღვრული 753037, სხვაობა 122873;
# მომხმარებელი 9704: მიიღო 14313, განსაზღვრული 23426, სხვაობა 9113;
# მომხმარებელი 9705: მიიღო 1362520, განსაზღვრული 902093, სხვაობა 460427;
# მომხმარებელი 9706: მიიღო 151711, განსაზღვრული 201763, სხვაობა 50052;
# მომხმარებელი 9707: მიიღო 9537, განსაზღვრული 20277, სხვაობა 10740;
# მომხმარებელი 9708: მიიღო 88393, განსაზღვრული 144232, სხვაობა 55839;
# მომხმარებელი 9709: მიიღო 10564, განსაზღვრული 17420, სხვაობა 6856;
# მომხმარებელი 9710: მიიღო 702302, განსაზღვრული 889081, სხვაობა 186779;
# მომხმარებელი 9711: მიიღო 380138, განსაზღვრული 387740, სხვაობა 7602;
# მომხმარებელი 9712: მიიღო 682484, განსაზღვრული 681792, სხვაობა 692;
# მომხმარებელი 9713: მიიღო 951883, განსაზღვრული 895591, სხვაობა 56292;
# მომხმარებელი 9714: მიიღო 270378, განსაზღვრული 422729, სხვაობა 152351;
# მომხმარებელი 9715: მიიღო 413073, განსაზღვრული 438139, სხვაობა 25066;
# მომხმარებელი 9716: მიიღო 139358, განსაზღვრული 185946, სხვაობა 46588;
# მომხმარებელი 9717: მიიღო 63623, განსაზღვრული 88253, სხვაობა 24630;
# მომხმარებელი 9718: მიიღო 54568, განსაზღვრული 89641, სხვაობა 35073;
# მომხმარებელი 9719: მიიღო 4496, განსაზღვრული 7625, სხვაობა 3129;
# მომხმარებელი 9720: მიიღო 71526, განსაზღვრული 94982, სხვაობა 23456;
# მომხმარებელი 9721: მიიღო 739890, განსაზღვრული 858622, სხვაობა 118732;
# მომხმარებელი 9722: მიიღო 54323, განსაზღვრული 75213, სხვაობა 20890;
# მომხმარებელი 9723: მიიღო 304775, განსაზღვრული 489061, სხვაობა 184286;
# მომხმარებელი 9724: მიიღო 22951, განსაზღვრული 26305, სხვაობა 3354;
# მომხმარებელი 9725: მიიღო 444561, განსაზღვრული 480558, სხვაობა 35997;
# მომხმარებელი 9726: მიიღო 121787, განსაზღვრული 160108, სხვაობა 38321;
# მომხმარებელი 9727: მიიღო 475267, განსაზღვრული 654563, სხვაობა 179296;
# მომხმარებელი 9728: მიიღო 954328, განსაზღვრული 1114452, სხვაობა 160124;
# მომხმარებელი 9729: მიიღო 64820, განსაზღვრული 66290, სხვაობა 1470;
# მომხმარებელი 9730: მიიღო 124105, განსაზღვრული 261837, სხვაობა 137732;
# მომხმარებელი 9731: მიიღო 188592, განსაზღვრული 327147, სხვაობა 138555;
# მომხმარებელი 9732: მიიღო 734931, განსაზღვრული 666278, სხვაობა 68653;
# მომხმარებელი 9733: მიიღო 115193, განსაზღვრული 147037, სხვაობა 31844;
# მომხმარებელი 9734: მიიღო 173412, განსაზღვრული 186970, სხვაობა 13558;
# მომხმარებელი 9735: მიიღო 49755, განსაზღვრული 70511, სხვაობა 20756;
# მომხმარებელი 9736: მიიღო 43617, განსაზღვრული 71737, სხვაობა 28120;
# მომხმარებელი 9737: მიიღო 353899, განსაზღვრული 395913, სხვაობა 42014;
# მომხმარებელი 9738: მიიღო 432187, განსაზღვრული 543278, სხვაობა 111091;
# მომხმარებელი 9739: მიიღო 1050886, განსაზღვრული 1064911, სხვაობა 14025;
# მომხმარებელი 9740: მიიღო 196534, განსაზღვრული 514710, სხვაობა 318176;
# მომხმარებელი 9741: მიიღო 28631, განსაზღვრული 48463, სხვაობა 19832;
# მომხმარებელი 9742: მიიღო 54871, განსაზღვრული 57922, სხვაობა 3051;
# მომხმარებელი 9743: მიიღო 255879, განსაზღვრული 346738, სხვაობა 90859;
# მომხმარებელი 9744: მიიღო 99804, განსაზღვრული 111714, სხვაობა 11910;
# მომხმარებელი 9745: მიიღო 44283, განსაზღვრული 71932, სხვაობა 27649;
# მომხმარებელი 9746: მიიღო 127550, განსაზღვრული 244372, სხვაობა 116822;
# მომხმარებელი 9747: მიიღო 274471, განსაზღვრული 280703, სხვაობა 6232;
# მომხმარებელი 9748: მიიღო 44824, განსაზღვრული 50726, სხვაობა 5902;
# მომხმარებელი 9749: მიიღო 402269, განსაზღვრული 745713, სხვაობა 343444;
# მომხმარებელი 9750: მიიღო 18643, განსაზღვრული 29575, სხვაობა 10932;
# მომხმარებელი 9751: მიიღო 205133, განსაზღვრული 270438, სხვაობა 65305;
# მომხმარებელი 9752: მიიღო 20429, განსაზღვრული 38388, სხვაობა 17959;
# მომხმარებელი 9753: მიიღო 206348, განსაზღვრული 200196, სხვაობა 6152;
# მომხმარებელი 9754: მიიღო 7040, განსაზღვრული 16749, სხვაობა 9709;
# მომხმარებელი 9755: მიიღო 56427, განსაზღვრული 98746, სხვაობა 42319;
# მომხმარებელი 9756: მიიღო 3304, განსაზღვრული 5558, სხვაობა 2254;
# მომხმარებელი 9757: მიიღო 46500, განსაზღვრული 75638, სხვაობა 29138;
# მომხმარებელი 9758: მიიღო 283, განსაზღვრული 4150, სხვაობა 3867;
# მომხმარებელი 9759: მიიღო 60694, განსაზღვრული 83489, სხვაობა 22795;
# მომხმარებელი 9760: მიიღო 15195, განსაზღვრული 23244, სხვაობა 8049;
# მომხმარებელი 9761: მიიღო 718065, განსაზღვრული 785226, სხვაობა 67161;
# მომხმარებელი 9762: მიიღო 18312, განსაზღვრული 17897, სხვაობა 415;
# მომხმარებელი 9763: მიიღო 57938, განსაზღვრული 63430, სხვაობა 5492;
# მომხმარებელი 9764: მიიღო 244600, განსაზღვრული 539522, სხვაობა 294922;
# მომხმარებელი 9765: მიიღო 246266, განსაზღვრული 275873, სხვაობა 29607;
# მომხმარებელი 9766: მიიღო 57424, განსაზღვრული 89852, სხვაობა 32428;
# მომხმარებელი 9767: მიიღო 4149, განსაზღვრული 6590, სხვაობა 2441;
# მომხმარებელი 9768: მიიღო 103107, განსაზღვრული 151432, სხვაობა 48325;
# მომხმარებელი 9769: მიიღო 19220, განსაზღვრული 32544, სხვაობა 13324;
# მომხმარებელი 9770: მიიღო 39015, განსაზღვრული 48769, სხვაობა 9754;
# მომხმარებელი 9771: მიიღო 402623, განსაზღვრული 463769, სხვაობა 61146;
# მომხმარებელი 9772: მიიღო 80538, განსაზღვრული 105904, სხვაობა 25366;
# მომხმარებელი 9773: მიიღო 110900, განსაზღვრული 157108, სხვაობა 46208;
# მომხმარებელი 9774: მიიღო 206180, განსაზღვრული 287675, სხვაობა 81495;
# მომხმარებელი 9775: მიიღო 66010, განსაზღვრული 101199, სხვაობა 35189;
# მომხმარებელი 9776: მიიღო 129292, განსაზღვრული 205023, სხვაობა 75731;
# მომხმარებელი 9777: მიიღო 208559, განსაზღვრული 295829, სხვაობა 87270;
# მომხმარებელი 9778: მიიღო 381599, განსაზღვრული 960432, სხვაობა 578833;
# მომხმარებელი 9779: მიიღო 469755, განსაზღვრული 593767, სხვაობა 124012;
# მომხმარებელი 9780: მიიღო 58516, განსაზღვრული 171055, სხვაობა 112539;
# მომხმარებელი 9781: მიიღო 210218, განსაზღვრული 198119, სხვაობა 12099;
# მომხმარებელი 9782: მიიღო 430705, განსაზღვრული 566631, სხვაობა 135926;
# მომხმარებელი 9783: მიიღო 76659, განსაზღვრული 85880, სხვაობა 9221;
# მომხმარებელი 9784: მიიღო 105553, განსაზღვრული 132727, სხვაობა 27174;
# მომხმარებელი 9785: მიიღო 51252, განსაზღვრული 93262, სხვაობა 42010;
# მომხმარებელი 9786: მიიღო 512687, განსაზღვრული 710299, სხვაობა 197612;
# მომხმარებელი 9787: მიიღო 109287, განსაზღვრული 139682, სხვაობა 30395;
# მომხმარებელი 9788: მიიღო 29109, განსაზღვრული 47829, სხვაობა 18720;
# მომხმარებელი 9789: მიიღო 50559, განსაზღვრული 59993, სხვაობა 9434;
# მომხმარებელი 9790: მიიღო 105277, განსაზღვრული 137071, სხვაობა 31794;
# მომხმარებელი 9791: მიიღო 2228, განსაზღვრული 6406, სხვაობა 4178;
# მომხმარებელი 9792: მიიღო 9404, განსაზღვრული 10902, სხვაობა 1498;
# მომხმარებელი 9793: მიიღო 150550, განსაზღვრული 236258, სხვაობა 85708;
# მომხმარებელი 9794: მიიღო 122101, განსაზღვრული 134201, სხვაობა 12100;
# მომხმარებელი 9795: მიიღო 41209, განსაზღვრული 105657, სხვაობა 64448;
# მომხმარებელი 9796: მიიღო 49810, განსაზღვრული 67112, სხვაობა 17302;
# მომხმარებელი 9797: მიიღო 30853, განსაზღვრული 83317, სხვაობა 52464;
# მომხმარებელი 9798: მიიღო 434502, განსაზღვრული 545993, სხვაობა 111491;
# მომხმარებელი 9799: მიიღო 13068, განსაზღვრული 18726, სხვაობა 5658;
# მომხმარებელი 9800: მიიღო 3099, განსაზღვრული 4330, სხვაობა 1231;
# მომხმარებელი 9801: მიიღო 194856, განსაზღვრული 397672, სხვაობა 202816;
# მომხმარებელი 9802: მიიღო 102939, განსაზღვრული 139195, სხვაობა 36256;
# მომხმარებელი 9803: მიიღო 35012, განსაზღვრული 40929, სხვაობა 5917;
# მომხმარებელი 9804: მიიღო 75990, განსაზღვრული 83135, სხვაობა 7145;
# მომხმარებელი 9805: მიიღო 380217, განსაზღვრული 473120, სხვაობა 92903;
# მომხმარებელი 9806: მიიღო 11769, განსაზღვრული 11712, სხვაობა 57;
# მომხმარებელი 9807: მიიღო 26059, განსაზღვრული 53670, სხვაობა 27611;
# მომხმარებელი 9808: მიიღო 551092, განსაზღვრული 609039, სხვაობა 57947;
# მომხმარებელი 9809: მიიღო 282905, განსაზღვრული 424841, სხვაობა 141936;
# მომხმარებელი 9810: მიიღო 115439, განსაზღვრული 214883, სხვაობა 99444;
# მომხმარებელი 9811: მიიღო 109729, განსაზღვრული 150504, სხვაობა 40775;
# მომხმარებელი 9812: მიიღო 2225, განსაზღვრული 8263, სხვაობა 6038;
# მომხმარებელი 9813: მიიღო 107803, განსაზღვრული 182109, სხვაობა 74306;
# მომხმარებელი 9814: მიიღო 98336, განსაზღვრული 121816, სხვაობა 23480;
# მომხმარებელი 9815: მიიღო 161381, განსაზღვრული 288734, სხვაობა 127353;
# მომხმარებელი 9816: მიიღო 807791, განსაზღვრული 718756, სხვაობა 89035;
# მომხმარებელი 9817: მიიღო 105089, განსაზღვრული 251474, სხვაობა 146385;
# მომხმარებელი 9818: მიიღო 10225, განსაზღვრული 13614, სხვაობა 3389;
# მომხმარებელი 9819: მიიღო 112007, განსაზღვრული 150376, სხვაობა 38369;
# მომხმარებელი 9820: მიიღო 17753, განსაზღვრული 44162, სხვაობა 26409;
# მომხმარებელი 9821: მიიღო 213964, განსაზღვრული 264498, სხვაობა 50534;
# მომხმარებელი 9822: მიიღო 48558, განსაზღვრული 73641, სხვაობა 25083;
# მომხმარებელი 9823: მიიღო 410020, განსაზღვრული 443418, სხვაობა 33398;
# მომხმარებელი 9824: მიიღო 206, განსაზღვრული 3882, სხვაობა 3676;
# მომხმარებელი 9825: მიიღო 244561, განსაზღვრული 265650, სხვაობა 21089;
# მომხმარებელი 9826: მიიღო 244769, განსაზღვრული 339444, სხვაობა 94675;
# მომხმარებელი 9827: მიიღო 9045, განსაზღვრული 12579, სხვაობა 3534;
# მომხმარებელი 9828: მიიღო 393609, განსაზღვრული 487622, სხვაობა 94013;
# მომხმარებელი 9829: მიიღო 3097, განსაზღვრული 5781, სხვაობა 2684;
# მომხმარებელი 9830: მიიღო 32517, განსაზღვრული 30910, სხვაობა 1607;
# მომხმარებელი 9831: მიიღო 209600, განსაზღვრული 202807, სხვაობა 6793;
# მომხმარებელი 9832: მიიღო 272573, განსაზღვრული 336571, სხვაობა 63998;
# მომხმარებელი 9833: მიიღო 12989, განსაზღვრული 51032, სხვაობა 38043;
# მომხმარებელი 9834: მიიღო 178260, განსაზღვრული 222850, სხვაობა 44590;
# მომხმარებელი 9835: მიიღო 13087, განსაზღვრული 20055, სხვაობა 6968;
# მომხმარებელი 9836: მიიღო 108003, განსაზღვრული 128390, სხვაობა 20387;
# მომხმარებელი 9837: მიიღო 239533, განსაზღვრული 336641, სხვაობა 97108;
# მომხმარებელი 9838: მიიღო 575532, განსაზღვრული 696898, სხვაობა 121366;
# მომხმარებელი 9839: მიიღო 7595, განსაზღვრული 16554, სხვაობა 8959;
# მომხმარებელი 9840: მიიღო 44944, განსაზღვრული 59286, სხვაობა 14342;
# მომხმარებელი 9841: მიიღო 64651, განსაზღვრული 62960, სხვაობა 1691;
# მომხმარებელი 9842: მიიღო 653, განსაზღვრული 8686, სხვაობა 8033;
# მომხმარებელი 9843: მიიღო 16605, განსაზღვრული 47474, სხვაობა 30869;
# მომხმარებელი 9844: მიიღო 307711, განსაზღვრული 324008, სხვაობა 16297;
# მომხმარებელი 9845: მიიღო 125, განსაზღვრული 1563, სხვაობა 1438;
# მომხმარებელი 9846: მიიღო 165400, განსაზღვრული 261656, სხვაობა 96256;
# მომხმარებელი 9847: მიიღო 52319, განსაზღვრული 88312, სხვაობა 35993;
# მომხმარებელი 9848: მიიღო 406557, განსაზღვრული 490600, სხვაობა 84043;
# მომხმარებელი 9849: მიიღო 66856, განსაზღვრული 72723, სხვაობა 5867;
# მომხმარებელი 9850: მიიღო 18980, განსაზღვრული 38731, სხვაობა 19751;
# მომხმარებელი 9851: მიიღო 158494, განსაზღვრული 172872, სხვაობა 14378;
# მომხმარებელი 9852: მიიღო 825, განსაზღვრული 5017, სხვაობა 4192;
# მომხმარებელი 9853: მიიღო 14074, განსაზღვრული 23458, სხვაობა 9384;
# მომხმარებელი 9854: მიიღო 73126, განსაზღვრული 87191, სხვაობა 14065;
# მომხმარებელი 9855: მიიღო 5468, განსაზღვრული 11309, სხვაობა 5841;
# მომხმარებელი 9856: მიიღო 2697, განსაზღვრული 11411, სხვაობა 8714;
# მომხმარებელი 9857: მიიღო 224400, განსაზღვრული 462432, სხვაობა 238032;
# მომხმარებელი 9858: მიიღო 269548, განსაზღვრული 303918, სხვაობა 34370;
# მომხმარებელი 9859: მიიღო 27804, განსაზღვრული 27180, სხვაობა 624;
# მომხმარებელი 9860: მიიღო 236311, განსაზღვრული 183820, სხვაობა 52491;
# მომხმარებელი 9861: მიიღო 520522, განსაზღვრული 490565, სხვაობა 29957;
# მომხმარებელი 9862: მიიღო 60090, განსაზღვრული 62205, სხვაობა 2115;
# მომხმარებელი 9863: მიიღო 213248, განსაზღვრული 354214, სხვაობა 140966;
# მომხმარებელი 9864: მიიღო 27693, განსაზღვრული 22473, სხვაობა 5220;
# მომხმარებელი 9865: მიიღო 175808, განსაზღვრული 272461, სხვაობა 96653;
# მომხმარებელი 9866: მიიღო 591270, განსაზღვრული 816378, სხვაობა 225108;
# მომხმარებელი 9867: მიიღო 557748, განსაზღვრული 597800, სხვაობა 40052;
# მომხმარებელი 9868: მიიღო 29000, განსაზღვრული 45804, სხვაობა 16804;
# მომხმარებელი 9869: მიიღო 170266, განსაზღვრული 357249, სხვაობა 186983;
# მომხმარებელი 9870: მიიღო 94791, განსაზღვრული 122115, სხვაობა 27324;
# მომხმარებელი 9871: მიიღო 7609, განსაზღვრული 8006, სხვაობა 397;
# მომხმარებელი 9872: მიიღო 62641, განსაზღვრული 114624, სხვაობა 51983;
# მომხმარებელი 9873: მიიღო 144323, განსაზღვრული 438280, სხვაობა 293957;
# მომხმარებელი 9874: მიიღო 232399, განსაზღვრული 282761, სხვაობა 50362;
# მომხმარებელი 9875: მიიღო 172120, განსაზღვრული 354360, სხვაობა 182240;
# მომხმარებელი 9876: მიიღო 23982, განსაზღვრული 58355, სხვაობა 34373;
# მომხმარებელი 9877: მიიღო 38231, განსაზღვრული 58034, სხვაობა 19803;
# მომხმარებელი 9878: მიიღო 159699, განსაზღვრული 202427, სხვაობა 42728;
# მომხმარებელი 9879: მიიღო 183890, განსაზღვრული 277098, სხვაობა 93208;
# მომხმარებელი 9880: მიიღო 35690, განსაზღვრული 51901, სხვაობა 16211;
# მომხმარებელი 9881: მიიღო 116041, განსაზღვრული 74968, სხვაობა 41073;
# მომხმარებელი 9882: მიიღო 676896, განსაზღვრული 682887, სხვაობა 5991;
# მომხმარებელი 9883: მიიღო 235711, განსაზღვრული 349691, სხვაობა 113980;
# მომხმარებელი 9884: მიიღო 5800, განსაზღვრული 16803, სხვაობა 11003;
# მომხმარებელი 9885: მიიღო 74036, განსაზღვრული 87366, სხვაობა 13330;
# მომხმარებელი 9886: მიიღო 657671, განსაზღვრული 776433, სხვაობა 118762;
# მომხმარებელი 9887: მიიღო 71823, განსაზღვრული 114934, სხვაობა 43111;
# მომხმარებელი 9888: მიიღო 119938, განსაზღვრული 175843, სხვაობა 55905;
# მომხმარებელი 9889: მიიღო 107482, განსაზღვრული 129336, სხვაობა 21854;
# მომხმარებელი 9890: მიიღო 3570, განსაზღვრული 3994, სხვაობა 424;
# მომხმარებელი 9891: მიიღო 633358, განსაზღვრული 764115, სხვაობა 130757;
# მომხმარებელი 9892: მიიღო 366, განსაზღვრული 3974, სხვაობა 3608;
# მომხმარებელი 9893: მიიღო 71724, განსაზღვრული 112889, სხვაობა 41165;
# მომხმარებელი 9894: მიიღო 4488, განსაზღვრული 6504, სხვაობა 2016;
# მომხმარებელი 9895: მიიღო 347050, განსაზღვრული 380924, სხვაობა 33874;
# მომხმარებელი 9896: მიიღო 21106, განსაზღვრული 26606, სხვაობა 5500;
# მომხმარებელი 9897: მიიღო 194223, განსაზღვრული 224600, სხვაობა 30377;

# %% [markdown]
# <span style="font-size: 16px;">საშუალო, მაქსიმალური და მინიმალური სხვაობები:</span>

# %%
diff_average = 0
diff_min = float("inf")
diff_max = float("-inf")

for i in users_diffs:
    curr_diff = users_diffs[i]
    diff_average += curr_diff
    diff_min = min(curr_diff, diff_min)
    diff_max = max(curr_diff, diff_max)
diff_average = int(diff_average / len(users_diffs))

diffs_to_plot = {"მინიმუმი": diff_min, "მაქსიმუმი": diff_max, "საშუალო": diff_average}
plot_items(diffs_to_plot, "", "მნიშვნელობა", "სხვაობათა მნიშვნელობები", colors = None, width = 10)
# Out:
# > მინიმუმი: 2
# > მაქსიმუმი: 1855704
# > საშუალო: 58588

# %% [markdown]
# <span style="font-size: 16px;">ეს მონაცემები მოდელის მომზადებაში დაგვეხმარება. **საშუალოზე დაბალი სხვაობის დიეტები შეგვიძლია ჩავთვალოთ, რომ კარგად შესრულებული დიეტაა და მათი მოდელისთვის გამოყენება უკეთესი შედეგის მომცემი უნდა იყოს**.</span>

# %% [markdown]
# <span style="font-size: 16px;">ახლა ვნახოთ, თუ როგორ არის დამოკიდებული სხვაობათა მნიშვნელობები მომხმარებელთა რაოდენობებზე. ვინაიდან საშუალო სხვაობა **58588**-ის ტოლია, უკეთესი იქნება, რომ მასზე ნაკლები მნიშვნელობებისთვის გამოვიყენოთ შედარებით პატარა შუალედები, ხოლო მასზე მეტისთვის (ვინაიდან მოდელისთვის დიდ მნიშვნელობას არ წარმოადგენს) შეგვიძლია დიდი შუალედების მონაცემები.</span>

# %%
# Set intervals for lower and upper diff diets (depending on average diff)
LOWER_INTERVAL = 10000
UPPER_INTERVAL = 150000

users_diffs_intervals = {}
users_diffs_intervals_lower = {}
users_diffs_intervals_upper = {}

curr_int_start = 0
# First count intervals before the average diff
while curr_int_start < diff_average:
    curr_int_end = curr_int_start + LOWER_INTERVAL
    curr_key = "{0}_{1}".format(curr_int_start, curr_int_end)
    curr_val = 0
    for i in users_diffs:
        curr_diff = users_diffs[i]
        if curr_diff >= curr_int_start and curr_diff < curr_int_end:
            curr_val += 1
    users_diffs_intervals[curr_key] = curr_val
    users_diffs_intervals_lower[curr_key] = curr_val
    curr_int_start = curr_int_end

# Then count intervals after the average diff until the max diff
while curr_int_start < diff_max:
    curr_int_end = curr_int_start + UPPER_INTERVAL
    curr_key = "{0}_{1}".format(curr_int_start, curr_int_end)
    curr_val = 0
    for i in users_diffs:
        curr_diff = users_diffs[i]
        if curr_diff >= curr_int_start and curr_diff < curr_int_end:
            curr_val += 1
    users_diffs_intervals_upper[curr_key] = curr_val
    curr_int_start = curr_int_end

# %% [markdown]
# <span style="font-size: 16px;">**სხვაობათა ინტერვალთა განაწილება საშუალოზე *დაბალ* სხვაობებისთვის:**</span>

# %%
plot_pie_with_legend(users_diffs_intervals_lower)

# %% [markdown]
# <span style="font-size: 16px;">**სხვაობათა ინტერვალთა განაწილება საშუალოზე *მაღალ* სხვაობებისთვის:**</span>

# %%
plot_pie_with_legend(users_diffs_intervals_upper)

# %% [markdown]
# <span style="font-size: 16px;">საშუალოზე მაღალი სხვაობის ინტერვალებისთვის ჩანს, რომ 500,000-ზე მეტი სხვაობის დიეტების რაოდენობა საკმაოდ ცოტა, *~1.3%*-ია. ასევე გასათვალისწინებელია, რომ ჩვენი მოდელისთვის ამხელა აცდენის მქონდე დიეტები სასარგებლო შედეგს არ მოგვცემს, შესაბამისად შეგვიძლია ეს შუალედები უარვყოთ:</span>

# %%
users_diffs_intervals_upper = {}

curr_int_start = 60000
while curr_int_start < 500000:
    curr_int_end = curr_int_start + UPPER_INTERVAL
    curr_key = "{0}_{1}".format(curr_int_start, curr_int_end)
    curr_val = 0
    for i in users_diffs:
        curr_diff = users_diffs[i]
        if curr_diff >= curr_int_start and curr_diff < curr_int_end:
            curr_val += 1
    users_diffs_intervals[curr_key] = curr_val
    users_diffs_intervals_upper[curr_key] = curr_val
    curr_int_start = curr_int_end

# %% [markdown]
# <span style="font-size: 16px;">**განახლებული სხვაობათა ინტერვალთა განაწილება საშუალოზე *მაღალ* სხვაობებისთვის:**</span>

# %%
plot_pie_with_legend(users_diffs_intervals_upper)

# %% [markdown]
# <span style="font-size: 16px;">**სხვაობათა ინტერვალთა განაწილება *ყველა* ინტერვალისთვის:**</span>

# %%
plot_pie_with_legend(users_diffs_intervals)

# %% [markdown]
# # მოდელისთვის მომზადება
# <span style="font-size: 16px;">ვინაიდან მომხმარებლის მომდევნო საკვების გასარკვევად მნიშვნელოვანია რომ მაგალითები ყოველდღიური და ჯანსაღი დიეტებიდან ავიღოთ, საჭიროა, რომ დიეტების ხანგრძლივობა არ იყოს ხანმოკლე. მოდელისთვის მოსამზადებლად თავიდაპირველად მონაცემებიდან ვნახოთ, თუ რომელი მომხმარებლის ჩანაწერები (დიეტები) არის ზუსტად 35 დღის, ან უფრო მეტი ხანგრძლივობის (35 დღეზე ხანრგრძლივი ჩანაწერებიდან გამოვიყენებთ მხოლოდ პირველ 35 დღეს).</span>

# %%
# Minimum needed amount of days for the user's diet
NEEDED_DAYS_FOR_DIET = 35

# We will keep track of all the users whose diets' days 
# are less than needed amount in this array
invalid_users = []

days_count = 0
all_users = 0
valid_diets_count = 0
valid_diets_days_count = 0
curr_user_id = train.iloc[0, 0]
for i in range(len(train.index)):
    # Get the details of the day for the current row
    curr_day_user_id = train.iloc[i, 0]

    if curr_day_user_id != curr_user_id:
        # We got to another user
        all_users += 1
        if days_count >= NEEDED_DAYS_FOR_DIET:
            valid_diets_count += 1
            valid_diets_days_count += days_count
        else:
            invalid_users.append(curr_user_id)
        curr_user_id = curr_day_user_id
        days_count = 0 
    days_count += 1

# Last check after the loop
if days_count >= NEEDED_DAYS_FOR_DIET:
    valid_diets_count += 1
    valid_diets_days_count += days_count
else:
    invalid_users.append(curr_user_id)
    
print('{0} მომხმარებლიდან {1} დღეზე ხანგრძლივი დიეტის ჩანაწერი არის {2} მომხმარებელზე'.format(
    all_users, NEEDED_DAYS_FOR_DIET, valid_diets_count))
print('აღნიშნულ მომხმარებლების საერთო დიეტის დღეების რაოდენობა კი ' + str(valid_diets_days_count) + '-ია')
# Out:
# 9895 მომხმარებლიდან 35 დღეზე ხანგრძლივი დიეტის ჩანაწერი არის 5425 მომხმარებელზე
# აღნიშნულ მომხმარებლების საერთო დიეტის დღეების რაოდენობა კი 527788-ია

# %% [markdown]
# <span style="font-size: 16px;">ახლა კი წავშალოთ იმ მომხმარებლების მონაცემები, რომელთა დიეტის ხანგრძლივობაც 35 დღეზე ნაკლებია. მიღებული მონაცემები შევინახოთ `valid_days_trained` ცვლადში.</span>

# %%
# First we make the copy of the original data
valid_days_train = train.copy()

# And now we drop the rows for the invalid users
i = 0
rows_to_drop = []
while i < len(valid_days_train.index):
    curr_user_id = valid_days_train.iloc[i, 0]
    if curr_user_id in invalid_users:
        rows_to_drop.append(i)
    i += 1
    
valid_days_train = valid_days_train.drop(rows_to_drop)

# %% [markdown]
# <span style="font-size: 16px;">შემდეგ ნაწილში ვნახოთ, თუ რომელი მომხმარებლების დიეტები არის ჩვენთვის ვალიდური (არ არის დარღვეული დიდი პროცენტობით) და დავტოვოთ მოხლოდ მათი ჩანაწერები. ამისათვის გამოვიყენოთ გაანალიზებული მონაცემები და ცხრილიდან ამოვიღოთ ჩანაწერები, რომელთა დიეტის მთლიანი მიღებულ და განსაზღვრულ რაოდენობათა სხვაობა საშუალოზე (`diff_average`-ზე) მცირეა. მიღებულ მონაცემებს შევინახავთ `good_diet_train` ცვლადში.</span>

# %%
# We store user ids of users whose diets are bad in this array
bad_diet_user_ids = []

for i in users_diffs:
    if users_diffs[i] > diff_average:
        bad_diet_user_ids.append(i)

print('{0} მომხმარებელს აქვს საშუალოზე მეტი სხვაობა'.format(len(bad_diet_user_ids)))
# Out:
# 3096 მომხმარებელს აქვს საშუალოზე მეტი სხვაობა

# %%
# First we make the copy of the original data
good_diet_train = train.copy()

# And now we drop the rows for the invalid users
i = 0
rows_to_drop = []
while i < len(good_diet_train.index):
    curr_user_id = good_diet_train.iloc[i, 0]
    if curr_user_id in bad_diet_user_ids:
        rows_to_drop.append(i)
    i += 1
    
good_diet_train = good_diet_train.drop(rows_to_drop)
